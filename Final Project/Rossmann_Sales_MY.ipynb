# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Supervised Learning
# ## Project: Sales Prediction for *Rossmann*

# %% [markdown]
# ----
# ## Load the Data
# Run the code cell below to load necessary Python libraries and load the census data. Note that the last column from this dataset, `'Sales'`, will be our target label . All other columns are features about each individual in the train database.

# %%
import warnings
warnings.filterwarnings("ignore", category = UserWarning, module = "matplotlib")

# loading packages
# basic + dates 
import numpy as np
import pandas as pd
from pandas import datetime

import operator
import matplotlib
matplotlib.use("Agg") #Needed to save figures
# data visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
# %matplotlib inline


# label encoder
from sklearn import preprocessing
# Import train_test_split
from sklearn.model_selection import train_test_split
# create a decorater to measure the model training and predicting elapsed time
import time
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# For Random Forest parameters
from sklearn.metrics import make_scorer
from sklearn.grid_search import GridSearchCV
# algorithms input

import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
# Set up XGBoost parameters
import scipy.stats as st
from sklearn.model_selection import RandomizedSearchCV
# Out:
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
types = {'CompetitionOpenSinceYear': np.dtype(int),
         'CompetitionOpenSinceMonth': np.dtype(int),
         'StateHoliday': np.dtype(str),
         'Promo2SinceWeek': np.dtype(int),
         'SchoolHoliday': np.dtype(float),
         'PromoInterval': np.dtype(str)}
# Load the dataset
train = pd.read_csv("train.csv",parse_dates=['Date'], dtype=types)
# Load test data
test = pd.read_csv("test.csv",parse_dates=['Date'], dtype=types)
# load additional store data
store = pd.read_csv("store.csv")

# %% [markdown]
# ** Featureset Exploration **
#
# * **Id** - an Id that represents a (Store, Date) duple within the test set
# * **Store** - a unique Id for each store
# * **Sales** - the turnover for any given day (this is what you are predicting)
# * **Customers** - the number of customers on a given day
# * **Open** - an indicator for whether the store was open: 0 = closed, 1 = open
# * **StateHoliday** - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# * **SchoolHoliday** - indicates if the (Store, Date) was affected by the closure of public schools
# * **StoreType** - differentiates between 4 different store models: a, b, c, d
# * **Assortment**- describes an assortment level: a = basic, b = extra, c = extended
# * **CompetitionDistance** - distance in meters to the nearest competitor store
# * **CompetitionOpenSince[Month/Year]** - gives the approximate year and month of the time the nearest competitor was opened
# * **Promo** - indicates whether a store is running a promo on that day
# * **Promo2** - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# * **Promo2Since[Year/Week]** - describes the year and calendar week when the store started participating in Promo2
# * **PromoInterval** - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %% [markdown]
# ----
# ## Exploratory Data Analysis
# Exploratory data analysis helps data scientist get a general idea and required processes about the dataset.

# %%
# input extra features
# keep all the information
data=pd.merge(train,store,on='Store',how='outer')

# %%
# data extraction basic
data['Year'] = data.Date.dt.year
data['Month'] = data.Date.dt.month
data['Day'] = data.Date.dt.day
data['WeekOfYear'] = data.Date.dt.weekofyear

# %%
data.info()

# %%
display(data.isnull().sum())

# %%
# no promo = no information about the promo?
_ = data[pd.isnull(data.Promo2SinceWeek)]
_[_.Promo2 != 0].shape

# %% [markdown]
# If there's no Promo2 then there's no information about it. We can replace **Promo2SinceWeek, Promo2SinceYear** values by zeros. The same goes for tha variables deducted from the competition, **CompetitionOpenSinceMonth and CompetitionOpenSinceYear**.

# %%
display(data.describe(include='all').T)

# %%
nondate_cate=['StateHoliday','StoreType','Assortment','PromoInterval']

for feature in nondate_cate:
    plt.figure(figsize=(8,3))
    sns.violinplot(x=data[feature],y=data.Sales)
    plt.show()

# %%
drop_labels=['Store','Open','StateHoliday','StoreType','Assortment','PromoInterval']
data_cor=data.drop(drop_labels,axis=1).corr()

# %%
sns.set()
plt.figure(figsize=(10,10))
# Generate a mask for the upper triangle
mask = np.zeros_like(data_cor, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(data_cor,vmin=0,vmax=1, mask = mask,annot=True,
            square = True, linewidths = .5, cmap = "BuPu")

# %%
sns.set(font_scale=1.5)#set font size
sns.factorplot(data = data, x = 'Month', y = "Sales", 
               col_order=['a','b','c','d'],
               hue_order=['a','b','c'],
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'Assortment',
               row = 'Promo', # per promo in the store in rows
               )

# %% [markdown]
# ## Data Preprocessing and feature engineering
# Before data can be used as input for machine learning algorithms, it often must be cleaned, formatted, and restructured — this is typically known as **preprocessing**. There are some qualities about certain features that must be adjusted. This preprocessing can help tremendously with the outcome and predictive power of nearly all learning algorithms.

# %%
data['CompetitionDistance'].fillna(data['CompetitionDistance'].median(), inplace = True)
data.fillna(0,inplace=True)
data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
(data.Month - data.CompetitionOpenSinceMonth)
data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear) + \
(data.WeekOfYear - data.Promo2SinceWeek) / 4.0

# %%
# feature selection to drop repeating columns
label_data = data['Sales'] # Seperate label from training dataset
droplabels=['PromoInterval','Date','Sales','Customers','StateHoliday']
feature_data = data.drop(droplabels, axis = 1)

# %%
# log transformation of Sales
label_data.apply(lambda x: np.log(x + 1));

# %% [markdown]
# From the table in **Exploring the Data** above, we can see there are several features for each record that are non-numeric. Typically, learning algorithms expect input to be numeric, which requires that non-numeric features (called *categorical variables*) be converted. One popular way to convert categorical variables is by using the **one-hot encoding** scheme. One-hot encoding creates a _"dummy"_ variable for each possible category of each non-numeric feature. For example, assume `someFeature` has three possible entries: `A`, `B`, or `C`. We then encode this feature into `someFeature_A`, `someFeature_B` and `someFeature_C`.
#
# |   | someFeature |                    | someFeature_A | someFeature_B | someFeature_C |
# | :-: | :-: |                            | :-: | :-: | :-: |
# | 0 |  B  |  | 0 | 1 | 0 |
# | 1 |  C  | ----> one-hot encode ----> | 0 | 0 | 1 |
# | 2 |  A  |  | 1 | 0 | 0 |

# %%
# One-hot encode the 'features_log_minmax_transform' data using pandas.get_dummies()
features_final = pd.get_dummies(feature_data,columns=['StoreType','Assortment'])


# Print the number of features after one-hot encoding
encoded = list(features_final.columns)
print ("{} total features after one-hot encoding.".format(len(encoded)))

# the encoded feature names
#print (encoded)

# %% [markdown]
# ### Shuffle and Split Data
# Now all _categorical variables_ have been converted into numerical features, and all numerical features have been normalized. As always, we will now split the data (both features and their labels) into training and test sets. 80% of the data will be used for training and 20% for testing.
#
# Run the code cell below to perform this split.

# %%
# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_final, 
                                                    label_data, 
                                                    test_size = 0.2, 
                                                    random_state = 77)

# Show the results of the split
print ("Training set has {} samples.".format(X_train.shape[0]))
print ("Testing set has {} samples.".format(X_test.shape[0]))

# %% [markdown]
# ----
# ## Evaluating Model Performance
# In this section, we will investigate four different algorithms, and determine which is best at modeling the data. Three of these algorithms will be supervised learners of your choice, and the fourth algorithm is known as a *naive predictor*.

# %% [markdown]
# ###  Supervised Learning Models
# **The following are some of the supervised learning models that are currently available in** [`scikit-learn`](http://scikit-learn.org/stable/supervised_learning.html) **that you may choose from:**
# - Gaussian Naive Bayes (GaussianNB)
# - Decision Trees
# - Ensemble Methods (Bagging, AdaBoost, Random Forest, Gradient Boosting)
# - K-Nearest Neighbors (KNeighbors)
# - Stochastic Gradient Descent Classifier (SGDC)
# - Support Vector Machines (SVM)
# - Logistic Regression

# %% [markdown]
# ### Implementation - Creating a Training and Predicting Pipeline
# To properly evaluate the performance of each model you've chosen, it's important that you create a training and predicting pipeline that allows you to quickly and effectively train models using various sizes of training data and perform predictions on the testing data. Your implementation here will be used in the following section.
# In the code block below, you will need to implement the following:
#  - Import `fbeta_score` and `accuracy_score` from [`sklearn.metrics`](http://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics).
#  - Fit the learner to the sampled training data and record the training time.
#  - Perform predictions on the test data `X_test`, and also on the first 300 training points `X_train[:300]`.
#    - Record the total prediction time.
#  - Calculate the accuracy score for both the training subset and testing set.
#  - Calculate the F-score for both the training subset and testing set.
#    - Make sure that you set the `beta` parameter!

# %%
def elapsed_time(f):
    def wrapper(*args,**kwargs):
        t1=time.time()
        f(*args,**kwargs)
        t2=time.time()
        print('Elapsed time:{0:.2f} ms,{1:.2f} mins'.format((t2-t1) * 1000,(t2 - t1) / 60))
    return wrapper

@elapsed_time
def pipeline(learner,X_train,y_train,X_test,y_test):
    regr = learner(random_state=77)
    regr.fit(X_train, y_train)
    r2=r2_score(y_test, regr.predict(X_test))
    return print("For this algorithm, the percentage error of R2 is {0:.2f}".format((1-r2)*100))

# %%
pipeline(RandomForestRegressor,X_train,y_train,X_test,y_test)
pipeline(XGBRegressor,X_train,y_train,X_test,y_test)

# %% [markdown]
# ----
# ## Improving Results
# In this final section, you will choose from the three supervised learning models the *best* model to use on the student data. You will then perform a grid search optimization for the model over the entire training set (`X_train` and `y_train`) by tuning at least one parameter to improve upon the untuned model's F-score.

# %% [markdown]
# #### XGBoost key Parameters
#
#
# - `learning_rate`: Step size used in updating weights. Lower value means slower training but better convergence.
# - `n_estimators`: Total number of iterations.
# - `subsample`: The ratio of training data used in each iteration; combat overfitting. Should be configured in the range of 30% to 80% of the training dataset, and compared to a value of 100% for no sampling.
# - `colsample_bytree`: The ratio of features used in each iteration, default 1.
# - `max_depth`: The maximum depth of each tree. If we do not limit max depth, gradient boosting would eventually overfit.
# - `early_stopping_rounds`: If there's no increase in validation score for a given number of iterations, the algorithm will stop early, also combats overfitting.
# - `n_jobs`:Number of parallel threads used to run xgboost.

# %%
'''
The following three cells is referenced from one of the Kaggle kernels, 
and it is used for tuning parameters from clear visulization instead of randomly guessing. 
'''


def evaluate_param(clf,parameter, num_range, index):
    scorer = make_scorer(r2_score)
    grid_search = GridSearchCV(clf, param_grid = {parameter: num_range}, scoring=scorer)
    try:
        grid_search.fit(X_train, np.ravel(y_train[:]),early_stopping_rounds=50)
    except:
        grid_search.fit(X_train, np.ravel(y_train[:]))
    
    df = {}
    
    for i, score in enumerate(grid_search.grid_scores_):
        df[score[0][parameter]] = score[1]
       
    
    df = pd.DataFrame.from_dict(df, orient='index')
    df.reset_index(level=0, inplace=True)
    df = df.sort_values(by='index')
 
    plt.subplot(3,2,index)
    plot = plt.plot(df['index'], df[0])
    plt.title(parameter)
    return plot, df

# %%
# set up random forest regressor parameters

# parameters visualization for narrow down numerical parameters to a certain range
# Max 6 sets of parameters
param_grid = {"n_estimators": np.arange(2, 100, 10),
              "max_features": np.arange(5, 20, 1),
              "min_samples_split": np.arange(2,80,10),
              "min_samples_leaf": np.arange(1,10,1),
              "max_leaf_nodes": np.arange(2,100,10),
              "min_weight_fraction_leaf": np.arange(0.,0.5,0.1)}

index = 1

clf=RandomForestRegressor(random_state=77) #Initialize the regressor

plt.figure(figsize=(16,12))
for parameter, param_range in dict.items(param_grid):   
    evaluate_param(clf,parameter, param_range, index)
    index += 1

# %% [markdown]
# XGBoost parameters refer to this [link](http://xgboost.readthedocs.io/en/latest/parameter.html) and the xgboost scikit-learn API for python is this [link](http://xgboost.readthedocs.io/en/latest/python/python_api.html?highlight=xgboost%20sklearn#module-xgboost.sklearn)

# %% [markdown]
# ## Redo the data preprocess

# %%
# Assume store open, if not provided
train.fillna(1, inplace=True)
test.fillna(1, inplace=True)

# %%
#Consider only open stores for training. Closed stores wont count into the score.
train = train[train["Open"] != 0]
#Use only Sales bigger then zero. Simplifies calculation of rmspe
train = train[train["Sales"] > 0]

# %%
# input extra features
train_data=pd.merge(train,store,on='Store',how='left')
test_data=pd.merge(test,store,on='Store',how='left')

# %%
# Gather some features referenced from Kaggle kernel


def build_features(features, data):
    # remove NaNs
    data.fillna(0, inplace=True)
    data.loc[data.Open.isnull(), 'Open'] = 1
    # Use some properties directly
    features.extend(['Store', 'CompetitionDistance', 'Promo', 'Promo2', 'SchoolHoliday'])

    # Label encode some features
    features.extend(['StoreType', 'Assortment', 'StateHoliday'])
    mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
    data.StoreType.replace(mappings, inplace=True)
    data.Assortment.replace(mappings, inplace=True)
    data.StateHoliday.replace(mappings, inplace=True)

    features.extend(['DayOfWeek', 'Month', 'Day', 'Year', 'WeekOfYear'])
    data['Year'] = data.Date.dt.year
    data['Month'] = data.Date.dt.month
    data['Day'] = data.Date.dt.day
    data['DayOfWeek'] = data.Date.dt.dayofweek
    data['WeekOfYear'] = data.Date.dt.weekofyear
    # CompetionOpen en PromoOpen from https://www.kaggle.com/ananya77041/rossmann-store-sales/randomforestpython/code
    # Calculate time competition open time in months
    features.append('CompetitionOpen')
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
        (data.Month - data.CompetitionOpenSinceMonth)
    # Promo open time in months
    features.append('PromoOpen')
    data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0
    data['PromoOpen'] = data.PromoOpen.apply(lambda x: x if x > 0 else 0)
    data.loc[data.Promo2SinceYear == 0, 'PromoOpen'] = 0

    # Indicate that sales on that day are in promo interval
    features.append('IsPromoMonth')
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', \
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['monthStr'] = data.Month.map(month2str)
    data.loc[data.PromoInterval == 0, 'PromoInterval'] = ''
    data['IsPromoMonth'] = 0
    for interval in data.PromoInterval.unique():
        if interval != '':
            for month in interval.split(','):
                data.loc[(data.monthStr == month) & (data.PromoInterval == interval), 'IsPromoMonth'] = 1
    # Insert a feature to differ different zones from state holidays
    features.append('zone')
    for storeid in data.Store.unique():
        data.loc[(data.Store == storeid) & (data.StateHoliday == 0),'zone'] = 0
        zonenum=data.loc[(data.Store == storeid),'zone'].isnull().sum()
        # store the number to holidaycount feature
        data.loc[(data.Store == storeid)& (data.zone.isnull()),'zone'] = zonenum
    # alter the data type to a proper one
    altintfeatures=['SchoolHoliday','CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear','zone']
    data[altintfeatures]=data[altintfeatures].astype(np.int64)    
    return data

# %%
features = []
build_features(features, train_data)
build_features([], test_data);

# %%
train_data.set_index('Date',inplace=True)
test_data.set_index('Date',inplace=True)
train_data.sort_index(ascending = True,inplace=True)

# %%
# Evaluation Metric setup
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

# %%
'''
# create a holdout data set of last 6 weeks from the data set for model validation 
X_holdout=train_data['2015-06-20':]
y_holdout = np.log1p(X_holdout.Sales)

train_valid=train_data[:'2015-06-20']

X_train, X_valid = train_test_split(train_valid, test_size=0.012)
y_train = np.log1p(X_train.Sales)
y_valid = np.log1p(X_valid.Sales)

dtrain = xgb.DMatrix(X_train[features], y_train)
dvalid = xgb.DMatrix(X_valid[features], y_valid)

watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
'''

# %%
"""
# Time consuming parameter tuning
params_sk = {
            
            'subsample':0.9,#add randomness to make training robust to noise
            'colsample_bytree':0.7,#add randomness to make training robust to noise
            'num_boost_round':7000,
            "tree_method":'hist',#default 'auto'
            "grow_policy":'lossguide',#default 'depthwise'
            'seed':42
            }     

params_grid = {  
    'learning_rate':np.arange(0.01, 0.1, 0.01),
    'max_depth': np.arange(10, 20, 1),#control model complexity
    'reg_alpha': np.arange(0, 20, 2),#control model complexity
}

skrg = XGBRegressor(**params_sk)
skrg.fit((X_train[features]), y_train)

search_sk = RandomizedSearchCV(skrg, params_grid,scoring='neg_mean_squared_error',n_jobs=-1, cv = 5) # 5 fold cross validation
search_sk.fit((X_valid[features]), y_valid)

# best parameters
print(search_sk.best_params_); print(search_sk.best_score_)
"""

# %%
params = {"objective": "reg:linear",
          "booster" : "gbtree",
          "eta": 0.015,
          "max_depth": 16,
          "subsample": 0.8,
          "colsample_bytree": 0.7,
          "alpha":6,#L1 regularization term on weights, increase this value will make model more conservative.
          "tree_method":'hist',#default 'auto'
          "grow_policy":'lossguide',#default=’depthwise’
          "silent": 1,
          "seed": 42
          }

num_boost_round = 10000
early_stopping_rounds = 5000

# %%
X_train, X_valid = train_test_split(train_data, test_size=0.1,shuffle=False)
y_train = np.log1p(X_train.Sales)
y_valid = np.log1p(X_valid.Sales)

dtrain = xgb.DMatrix(X_train[features], y_train)
dvalid = xgb.DMatrix(X_valid[features], y_valid)

watchlist = [(dtrain, 'train'), (dvalid, 'eval')]

model_final = xgb.train(params, dtrain, num_boost_round, evals=watchlist, 
  early_stopping_rounds=early_stopping_rounds,feval=rmspe_xg, verbose_eval=True)
# Out:
# [0]	train-rmse:8.14036	eval-rmse:8.18655	train-rmspe:0.99985	eval-rmspe:0.999858
# Multiple eval metrics have been passed: 'eval-rmspe' will be used for early stopping.
#
# Will train until eval-rmspe hasn't improved in 5000 rounds.
# [1]	train-rmse:8.01853	eval-rmse:8.06476	train-rmspe:0.999808	eval-rmspe:0.999818
# [2]	train-rmse:7.89855	eval-rmse:7.94458	train-rmspe:0.999762	eval-rmspe:0.999774
# [3]	train-rmse:7.78033	eval-rmse:7.82656	train-rmspe:0.99971	eval-rmspe:0.999726
# [4]	train-rmse:7.66392	eval-rmse:7.71005	train-rmspe:0.999654	eval-rmspe:0.999672
# [5]	train-rmse:7.54926	eval-rmse:7.59533	train-rmspe:0.999591	eval-rmspe:0.999612
# [6]	train-rmse:7.43633	eval-rmse:7.48213	train-rmspe:0.999521	eval-rmspe:0.999546
# [7]	train-rmse:7.32505	eval-rmse:7.37106	train-rmspe:0.999445	eval-rmspe:0.999474
# [8]	train-rmse:7.21548	eval-rmse:7.26125	train-rmspe:0.999361	eval-rmspe:0.999394
# [9]	train-rmse:7.10752	eval-rmse:7.15346	train-rmspe:0.999268	eval-rmspe:0.999307
# [10]	train-rmse:7.00118	eval-rmse:7.04729	train-rmspe:0.999168	eval-rmspe:0.999211
# [11]	train-rmse:6.89648	eval-rmse:6.94255	train-rmspe:0.999057	eval-rmspe:0.999106
# [12]	train-rmse:6.79333	eval-rmse:6.83949	train-rmspe:0.998936	eval-rmspe:0.998992
# [13]	train-rmse:6.69177	eval-rmse:6.73812	train-rmspe:0.998804	eval-rmspe:0.998867
# [14]	train-rmse:6.59173	eval-rmse:6.63804	train-rmspe:0.99866	eval-rmspe:0.998731
# [15]	train-rmse:6.49317	eval-rmse:6.53946	train-rmspe:0.998504	eval-rmspe:0.998583
# [16]	train-rmse:6.39607	eval-rmse:6.44236	train-rmspe:0.998335	eval-rmspe:0.998423
# [17]	train-rmse:6.30043	eval-rmse:6.34687	train-rmspe:0.998152	eval-rmspe:0.99825
# [18]	train-rmse:6.20625	eval-rmse:6.25279	train-rmspe:0.997953	eval-rmspe:0.998062
# [19]	train-rmse:6.11348	eval-rmse:6.16015	train-rmspe:0.997738	eval-rmspe:0.997858
# [20]	train-rmse:6.02209	eval-rmse:6.06892	train-rmspe:0.997506	eval-rmspe:0.997639
# [21]	train-rmse:5.9321	eval-rmse:5.97884	train-rmspe:0.997256	eval-rmspe:0.997402
# [22]	train-rmse:5.84345	eval-rmse:5.8903	train-rmspe:0.996987	eval-rmspe:0.997148
# [23]	train-rmse:5.75613	eval-rmse:5.80311	train-rmspe:0.996698	eval-rmspe:0.996874
# [24]	train-rmse:5.67014	eval-rmse:5.71708	train-rmspe:0.996387	eval-rmspe:0.99658
# [25]	train-rmse:5.58542	eval-rmse:5.63255	train-rmspe:0.996054	eval-rmspe:0.996265
# [26]	train-rmse:5.50204	eval-rmse:5.5491	train-rmspe:0.995696	eval-rmspe:0.995926
# [27]	train-rmse:5.41985	eval-rmse:5.46713	train-rmspe:0.995315	eval-rmspe:0.995566
# [28]	train-rmse:5.33897	eval-rmse:5.3861	train-rmspe:0.994906	eval-rmspe:0.995177
# [29]	train-rmse:5.25925	eval-rmse:5.30632	train-rmspe:0.994471	eval-rmspe:0.994765
# [30]	train-rmse:5.18072	eval-rmse:5.228	train-rmspe:0.994008	eval-rmspe:0.994328
# [31]	train-rmse:5.10337	eval-rmse:5.15086	train-rmspe:0.993515	eval-rmspe:0.993862
# [32]	train-rmse:5.0272	eval-rmse:5.07469	train-rmspe:0.99299	eval-rmspe:0.993365
# [33]	train-rmse:4.95217	eval-rmse:4.99974	train-rmspe:0.992433	eval-rmspe:0.992839
# [34]	train-rmse:4.87826	eval-rmse:4.92582	train-rmspe:0.991843	eval-rmspe:0.99228
# [35]	train-rmse:4.80547	eval-rmse:4.85315	train-rmspe:0.991217	eval-rmspe:0.991687
# [36]	train-rmse:4.73376	eval-rmse:4.78149	train-rmspe:0.990556	eval-rmspe:0.991062
# [37]	train-rmse:4.66314	eval-rmse:4.71105	train-rmspe:0.989856	eval-rmspe:0.990401
# [38]	train-rmse:4.5936	eval-rmse:4.6416	train-rmspe:0.989116	eval-rmspe:0.989701
# [39]	train-rmse:4.52511	eval-rmse:4.57315	train-rmspe:0.988335	eval-rmspe:0.988963
# [40]	train-rmse:4.45765	eval-rmse:4.50559	train-rmspe:0.987512	eval-rmspe:0.988182
# [41]	train-rmse:4.39121	eval-rmse:4.43919	train-rmspe:0.986646	eval-rmspe:0.987363
# [42]	train-rmse:4.32573	eval-rmse:4.37378	train-rmspe:0.985739	eval-rmspe:0.986504
# [43]	train-rmse:4.26125	eval-rmse:4.30933	train-rmspe:0.984783	eval-rmspe:0.985599
# [44]	train-rmse:4.19775	eval-rmse:4.24595	train-rmspe:0.98378	eval-rmspe:0.984651
# [45]	train-rmse:4.13523	eval-rmse:4.18338	train-rmspe:0.982727	eval-rmspe:0.983654
# [46]	train-rmse:4.07369	eval-rmse:4.12186	train-rmspe:0.981619	eval-rmspe:0.982604
# [47]	train-rmse:4.01305	eval-rmse:4.06115	train-rmspe:0.980462	eval-rmspe:0.981507
# [48]	train-rmse:3.95327	eval-rmse:4.00128	train-rmspe:0.979258	eval-rmspe:0.980365
# [49]	train-rmse:3.89444	eval-rmse:3.9423	train-rmspe:0.977995	eval-rmspe:0.979164
# [50]	train-rmse:3.83652	eval-rmse:3.88446	train-rmspe:0.976674	eval-rmspe:0.977915
# [51]	train-rmse:3.77944	eval-rmse:3.82748	train-rmspe:0.975299	eval-rmspe:0.976615
# [52]	train-rmse:3.72321	eval-rmse:3.77138	train-rmspe:0.973869	eval-rmspe:0.975262
# [53]	train-rmse:3.66781	eval-rmse:3.71605	train-rmspe:0.972383	eval-rmspe:0.973856
# [54]	train-rmse:3.61329	eval-rmse:3.66165	train-rmspe:0.970832	eval-rmspe:0.97239
# [55]	train-rmse:3.55956	eval-rmse:3.60802	train-rmspe:0.969225	eval-rmspe:0.97087
# [56]	train-rmse:3.50661	eval-rmse:3.55513	train-rmspe:0.967559	eval-rmspe:0.969292
# [57]	train-rmse:3.45446	eval-rmse:3.50304	train-rmspe:0.965831	eval-rmspe:0.967656
# [58]	train-rmse:3.40311	eval-rmse:3.45167	train-rmspe:0.96404	eval-rmspe:0.965956
# [59]	train-rmse:3.35255	eval-rmse:3.40114	train-rmspe:0.962181	eval-rmspe:0.964195
# [60]	train-rmse:3.30273	eval-rmse:3.35136	train-rmspe:0.960261	eval-rmspe:0.962374
# [61]	train-rmse:3.25373	eval-rmse:3.30224	train-rmspe:0.95826	eval-rmspe:0.960471
# [62]	train-rmse:3.20545	eval-rmse:3.25407	train-rmspe:0.956198	eval-rmspe:0.958521
# [63]	train-rmse:3.15789	eval-rmse:3.20646	train-rmspe:0.954069	eval-rmspe:0.956499
# [64]	train-rmse:3.11104	eval-rmse:3.15957	train-rmspe:0.951875	eval-rmspe:0.954415
# [65]	train-rmse:3.0649	eval-rmse:3.11337	train-rmspe:0.949611	eval-rmspe:0.952266
# [66]	train-rmse:3.01944	eval-rmse:3.06791	train-rmspe:0.947281	eval-rmspe:0.950053
# [67]	train-rmse:2.97472	eval-rmse:3.02305	train-rmspe:0.944873	eval-rmspe:0.947761
# [68]	train-rmse:2.93066	eval-rmse:2.97913	train-rmspe:0.942395	eval-rmspe:0.945416
# [69]	train-rmse:2.88719	eval-rmse:2.93573	train-rmspe:0.939864	eval-rmspe:0.943018
# [70]	train-rmse:2.84444	eval-rmse:2.89299	train-rmspe:0.93725	eval-rmspe:0.940539
# [71]	train-rmse:2.80232	eval-rmse:2.8508	train-rmspe:0.934568	eval-rmspe:0.937985
# [72]	train-rmse:2.76087	eval-rmse:2.80949	train-rmspe:0.931807	eval-rmspe:0.935372
# [73]	train-rmse:2.72006	eval-rmse:2.76866	train-rmspe:0.928971	eval-rmspe:0.932677
# [74]	train-rmse:2.6798	eval-rmse:2.72825	train-rmspe:0.926085	eval-rmspe:0.92992
# [75]	train-rmse:2.64022	eval-rmse:2.6886	train-rmspe:0.923105	eval-rmspe:0.927082
# [76]	train-rmse:2.60118	eval-rmse:2.6496	train-rmspe:0.920073	eval-rmspe:0.924202
# [77]	train-rmse:2.56282	eval-rmse:2.61108	train-rmspe:0.916949	eval-rmspe:0.921221
# [78]	train-rmse:2.52487	eval-rmse:2.57315	train-rmspe:0.913799	eval-rmspe:0.918229
# [79]	train-rmse:2.48763	eval-rmse:2.53588	train-rmspe:0.910544	eval-rmspe:0.915129
# [80]	train-rmse:2.45095	eval-rmse:2.49907	train-rmspe:0.907221	eval-rmspe:0.911957
# [81]	train-rmse:2.41484	eval-rmse:2.46285	train-rmspe:0.903821	eval-rmspe:0.90871
# [82]	train-rmse:2.37928	eval-rmse:2.42722	train-rmspe:0.900351	eval-rmspe:0.905398
# [83]	train-rmse:2.34413	eval-rmse:2.39196	train-rmspe:0.896856	eval-rmspe:0.902044
# [84]	train-rmse:2.30954	eval-rmse:2.35741	train-rmspe:0.893283	eval-rmspe:0.898638
# [85]	train-rmse:2.27538	eval-rmse:2.32312	train-rmspe:0.889668	eval-rmspe:0.895179
# [86]	train-rmse:2.24191	eval-rmse:2.28956	train-rmspe:0.885943	eval-rmspe:0.89162
# [87]	train-rmse:2.20888	eval-rmse:2.25648	train-rmspe:0.88217	eval-rmspe:0.888019
# [88]	train-rmse:2.17639	eval-rmse:2.22408	train-rmspe:0.87832	eval-rmspe:0.88436
# [89]	train-rmse:2.14437	eval-rmse:2.19207	train-rmspe:0.874419	eval-rmspe:0.880634
# [90]	train-rmse:2.11291	eval-rmse:2.16051	train-rmspe:0.87043	eval-rmspe:0.876818
# [91]	train-rmse:2.08183	eval-rmse:2.12944	train-rmspe:0.866412	eval-rmspe:0.872984
# [92]	train-rmse:2.05129	eval-rmse:2.09893	train-rmspe:0.862313	eval-rmspe:0.869074
# [93]	train-rmse:2.02117	eval-rmse:2.06877	train-rmspe:0.858168	eval-rmspe:0.86511
# [94]	train-rmse:1.99143	eval-rmse:2.03896	train-rmspe:0.853986	eval-rmspe:0.861111
# [95]	train-rmse:1.96229	eval-rmse:2.00969	train-rmspe:0.849696	eval-rmspe:0.856988
# [96]	train-rmse:1.9336	eval-rmse:1.98102	train-rmspe:0.845355	eval-rmspe:0.852845
# [97]	train-rmse:1.90535	eval-rmse:1.95283	train-rmspe:0.840953	eval-rmspe:0.848643
# [98]	train-rmse:1.87753	eval-rmse:1.92493	train-rmspe:0.836503	eval-rmspe:0.844376
# [99]	train-rmse:1.85015	eval-rmse:1.89741	train-rmspe:0.831993	eval-rmspe:0.840038
# [100]	train-rmse:1.82317	eval-rmse:1.87043	train-rmspe:0.827441	eval-rmspe:0.835683
# [101]	train-rmse:1.79662	eval-rmse:1.84392	train-rmspe:0.822835	eval-rmspe:0.831287
# [102]	train-rmse:1.77022	eval-rmse:1.81735	train-rmspe:0.818266	eval-rmspe:0.826854
# [103]	train-rmse:1.7443	eval-rmse:1.79131	train-rmspe:0.813624	eval-rmspe:0.822367
# [104]	train-rmse:1.71894	eval-rmse:1.76592	train-rmspe:0.808887	eval-rmspe:0.817824
# [105]	train-rmse:1.69398	eval-rmse:1.74089	train-rmspe:0.804099	eval-rmspe:0.813218
# [106]	train-rmse:1.6691	eval-rmse:1.71591	train-rmspe:0.799367	eval-rmspe:0.80864
# [107]	train-rmse:1.64488	eval-rmse:1.69172	train-rmspe:0.794507	eval-rmspe:0.80398
# [108]	train-rmse:1.62101	eval-rmse:1.66775	train-rmspe:0.789613	eval-rmspe:0.799264
# [109]	train-rmse:1.59739	eval-rmse:1.64403	train-rmspe:0.784725	eval-rmspe:0.794561
# [110]	train-rmse:1.57413	eval-rmse:1.62078	train-rmspe:0.779798	eval-rmspe:0.789836
# [111]	train-rmse:1.55139	eval-rmse:1.59794	train-rmspe:0.77478	eval-rmspe:0.784992
# [112]	train-rmse:1.529	eval-rmse:1.57552	train-rmspe:0.769733	eval-rmspe:0.780133
# [113]	train-rmse:1.50677	eval-rmse:1.55314	train-rmspe:0.764717	eval-rmspe:0.775246
# [114]	train-rmse:1.48505	eval-rmse:1.53135	train-rmspe:0.75962	eval-rmspe:0.770331
# [115]	train-rmse:1.46363	eval-rmse:1.50971	train-rmspe:0.75451	eval-rmspe:0.765362
# [116]	train-rmse:1.44238	eval-rmse:1.48838	train-rmspe:0.749423	eval-rmspe:0.760399
# [117]	train-rmse:1.42153	eval-rmse:1.46737	train-rmspe:0.744289	eval-rmspe:0.755411
# [118]	train-rmse:1.40113	eval-rmse:1.44693	train-rmspe:0.739092	eval-rmspe:0.750383
# [119]	train-rmse:1.38104	eval-rmse:1.42687	train-rmspe:0.733871	eval-rmspe:0.745354
# [120]	train-rmse:1.36126	eval-rmse:1.40703	train-rmspe:0.728637	eval-rmspe:0.740288
# [121]	train-rmse:1.34178	eval-rmse:1.38749	train-rmspe:0.72339	eval-rmspe:0.735209
# [122]	train-rmse:1.3226	eval-rmse:1.3682	train-rmspe:0.718133	eval-rmspe:0.730095
# [123]	train-rmse:1.30375	eval-rmse:1.34907	train-rmspe:0.712851	eval-rmspe:0.72491
# [124]	train-rmse:1.28496	eval-rmse:1.33023	train-rmspe:0.707626	eval-rmspe:0.719839
# [125]	train-rmse:1.26667	eval-rmse:1.31195	train-rmspe:0.702323	eval-rmspe:0.714704
# [126]	train-rmse:1.24842	eval-rmse:1.29367	train-rmspe:0.697088	eval-rmspe:0.709623
# [127]	train-rmse:1.23049	eval-rmse:1.27571	train-rmspe:0.691831	eval-rmspe:0.704473
# [128]	train-rmse:1.21277	eval-rmse:1.25794	train-rmspe:0.686581	eval-rmspe:0.699362
# [129]	train-rmse:1.19543	eval-rmse:1.2406	train-rmspe:0.681297	eval-rmspe:0.694235
# [130]	train-rmse:1.17852	eval-rmse:1.22356	train-rmspe:0.675974	eval-rmspe:0.689028
# [131]	train-rmse:1.1619	eval-rmse:1.20684	train-rmspe:0.67064	eval-rmspe:0.683816
# [132]	train-rmse:1.14545	eval-rmse:1.19023	train-rmspe:0.665334	eval-rmspe:0.678606
# [133]	train-rmse:1.12923	eval-rmse:1.1739	train-rmspe:0.659998	eval-rmspe:0.673401
# [134]	train-rmse:1.11304	eval-rmse:1.15775	train-rmspe:0.654746	eval-rmspe:0.668284
# [135]	train-rmse:1.0973	eval-rmse:1.14197	train-rmspe:0.649461	eval-rmspe:0.663118
# [136]	train-rmse:1.08192	eval-rmse:1.1265	train-rmspe:0.644155	eval-rmspe:0.657909
# [137]	train-rmse:1.06668	eval-rmse:1.11112	train-rmspe:0.638878	eval-rmspe:0.652711
# [138]	train-rmse:1.05168	eval-rmse:1.09597	train-rmspe:0.633621	eval-rmspe:0.647527
# [139]	train-rmse:1.03691	eval-rmse:1.08106	train-rmspe:0.628374	eval-rmspe:0.642334
# [140]	train-rmse:1.02246	eval-rmse:1.06647	train-rmspe:0.62312	eval-rmspe:0.637136
# [141]	train-rmse:1.00826	eval-rmse:1.05212	train-rmspe:0.61787	eval-rmspe:0.631937
# [142]	train-rmse:0.994195	eval-rmse:1.03792	train-rmspe:0.612661	eval-rmspe:0.626778
# [143]	train-rmse:0.980271	eval-rmse:1.02397	train-rmspe:0.607475	eval-rmspe:0.621702
# [144]	train-rmse:0.966477	eval-rmse:1.01009	train-rmspe:0.602327	eval-rmspe:0.616598
# [145]	train-rmse:0.953066	eval-rmse:0.996644	train-rmspe:0.597174	eval-rmspe:0.611526
# [146]	train-rmse:0.93986	eval-rmse:0.983333	train-rmspe:0.592041	eval-rmspe:0.606455
# [147]	train-rmse:0.926509	eval-rmse:0.96996	train-rmspe:0.586968	eval-rmspe:0.601412
# [148]	train-rmse:0.913823	eval-rmse:0.95711	train-rmspe:0.581856	eval-rmspe:0.596313
# [149]	train-rmse:0.901332	eval-rmse:0.944458	train-rmspe:0.57677	eval-rmspe:0.591238
# [150]	train-rmse:0.888936	eval-rmse:0.931939	train-rmspe:0.571727	eval-rmspe:0.586221
# [151]	train-rmse:0.876841	eval-rmse:0.91981	train-rmspe:0.566703	eval-rmspe:0.581235
# [152]	train-rmse:0.864622	eval-rmse:0.907534	train-rmspe:0.561724	eval-rmspe:0.57629
# [153]	train-rmse:0.852932	eval-rmse:0.895749	train-rmspe:0.556761	eval-rmspe:0.571336
# [154]	train-rmse:0.841167	eval-rmse:0.884044	train-rmspe:0.551782	eval-rmspe:0.566481
# [155]	train-rmse:0.829823	eval-rmse:0.872654	train-rmspe:0.546865	eval-rmspe:0.561584
# [156]	train-rmse:0.818607	eval-rmse:0.86134	train-rmspe:0.541991	eval-rmspe:0.556713
# [157]	train-rmse:0.807651	eval-rmse:0.850182	train-rmspe:0.537151	eval-rmspe:0.551808
# [158]	train-rmse:0.796861	eval-rmse:0.838972	train-rmspe:0.532354	eval-rmspe:0.546828
# [159]	train-rmse:0.786262	eval-rmse:0.828332	train-rmspe:0.527598	eval-rmspe:0.542056
# [160]	train-rmse:0.775689	eval-rmse:0.817626	train-rmspe:0.522858	eval-rmspe:0.537255
# [161]	train-rmse:0.765347	eval-rmse:0.807094	train-rmspe:0.518156	eval-rmspe:0.532463
# [162]	train-rmse:0.755256	eval-rmse:0.796956	train-rmspe:0.513514	eval-rmspe:0.527778
# [163]	train-rmse:0.745199	eval-rmse:0.786642	train-rmspe:0.508907	eval-rmspe:0.523045
# [164]	train-rmse:0.73511	eval-rmse:0.776436	train-rmspe:0.50431	eval-rmspe:0.518394
# [165]	train-rmse:0.725504	eval-rmse:0.766809	train-rmspe:0.499777	eval-rmspe:0.513823
# [166]	train-rmse:0.715699	eval-rmse:0.757014	train-rmspe:0.49525	eval-rmspe:0.509267
# [167]	train-rmse:0.706426	eval-rmse:0.747556	train-rmspe:0.490797	eval-rmspe:0.504695
# [168]	train-rmse:0.697291	eval-rmse:0.738256	train-rmspe:0.48639	eval-rmspe:0.500173
# [169]	train-rmse:0.688309	eval-rmse:0.729142	train-rmspe:0.482039	eval-rmspe:0.495704
# [170]	train-rmse:0.679494	eval-rmse:0.720021	train-rmspe:0.477731	eval-rmspe:0.491187
# [171]	train-rmse:0.670708	eval-rmse:0.711106	train-rmspe:0.473453	eval-rmspe:0.48677
# [172]	train-rmse:0.661967	eval-rmse:0.702332	train-rmspe:0.469217	eval-rmspe:0.482436
# [173]	train-rmse:0.653563	eval-rmse:0.693787	train-rmspe:0.465044	eval-rmspe:0.478112
# [174]	train-rmse:0.645305	eval-rmse:0.685313	train-rmspe:0.460923	eval-rmspe:0.473797
# [175]	train-rmse:0.637207	eval-rmse:0.676905	train-rmspe:0.45686	eval-rmspe:0.469468
# [176]	train-rmse:0.629056	eval-rmse:0.668718	train-rmspe:0.452794	eval-rmspe:0.465294
# [177]	train-rmse:0.621214	eval-rmse:0.660632	train-rmspe:0.448807	eval-rmspe:0.461078
# [178]	train-rmse:0.613151	eval-rmse:0.652586	train-rmspe:0.444779	eval-rmspe:0.456959
# [179]	train-rmse:0.605412	eval-rmse:0.644795	train-rmspe:0.440802	eval-rmspe:0.452889
# [180]	train-rmse:0.597517	eval-rmse:0.636842	train-rmspe:0.436864	eval-rmspe:0.448808
# [181]	train-rmse:0.589639	eval-rmse:0.628985	train-rmspe:0.432939	eval-rmspe:0.444792
# [182]	train-rmse:0.582442	eval-rmse:0.621719	train-rmspe:0.429184	eval-rmspe:0.440871
# [183]	train-rmse:0.575306	eval-rmse:0.614434	train-rmspe:0.425486	eval-rmspe:0.436938
# [184]	train-rmse:0.568228	eval-rmse:0.607254	train-rmspe:0.421795	eval-rmspe:0.433042
# [185]	train-rmse:0.561101	eval-rmse:0.600019	train-rmspe:0.418138	eval-rmspe:0.429171
# [186]	train-rmse:0.554022	eval-rmse:0.592933	train-rmspe:0.414494	eval-rmspe:0.425345
# [187]	train-rmse:0.547249	eval-rmse:0.586103	train-rmspe:0.410959	eval-rmspe:0.421602
# [188]	train-rmse:0.540233	eval-rmse:0.579066	train-rmspe:0.407301	eval-rmspe:0.417846
# [189]	train-rmse:0.533502	eval-rmse:0.572326	train-rmspe:0.403766	eval-rmspe:0.41415
# [190]	train-rmse:0.526736	eval-rmse:0.565536	train-rmspe:0.400247	eval-rmspe:0.410447
# [191]	train-rmse:0.520428	eval-rmse:0.559093	train-rmspe:0.396902	eval-rmspe:0.406837
# [192]	train-rmse:0.514193	eval-rmse:0.552783	train-rmspe:0.393566	eval-rmspe:0.403279
# [193]	train-rmse:0.508229	eval-rmse:0.546553	train-rmspe:0.390357	eval-rmspe:0.39971
# [194]	train-rmse:0.502122	eval-rmse:0.540388	train-rmspe:0.38711	eval-rmspe:0.396252
# [195]	train-rmse:0.49637	eval-rmse:0.534559	train-rmspe:0.384007	eval-rmspe:0.392889
# [196]	train-rmse:0.490755	eval-rmse:0.5287	train-rmspe:0.380968	eval-rmspe:0.389489
# [197]	train-rmse:0.485153	eval-rmse:0.523011	train-rmspe:0.377937	eval-rmspe:0.386191
# [198]	train-rmse:0.479267	eval-rmse:0.517043	train-rmspe:0.374836	eval-rmspe:0.382826
# [199]	train-rmse:0.473751	eval-rmse:0.51133	train-rmspe:0.371823	eval-rmspe:0.379502
# [200]	train-rmse:0.468386	eval-rmse:0.505841	train-rmspe:0.368949	eval-rmspe:0.376271
# [201]	train-rmse:0.462992	eval-rmse:0.500353	train-rmspe:0.366019	eval-rmspe:0.373063
# [202]	train-rmse:0.457865	eval-rmse:0.49522	train-rmspe:0.363216	eval-rmspe:0.370036
# [203]	train-rmse:0.452585	eval-rmse:0.489861	train-rmspe:0.360272	eval-rmspe:0.366893
# [204]	train-rmse:0.447687	eval-rmse:0.484757	train-rmspe:0.357607	eval-rmspe:0.363844
# [205]	train-rmse:0.442765	eval-rmse:0.47976	train-rmspe:0.354916	eval-rmspe:0.360884
# [206]	train-rmse:0.438028	eval-rmse:0.474919	train-rmspe:0.352343	eval-rmspe:0.357981
# [207]	train-rmse:0.433424	eval-rmse:0.470114	train-rmspe:0.349832	eval-rmspe:0.355088
# [208]	train-rmse:0.428934	eval-rmse:0.465411	train-rmspe:0.347405	eval-rmspe:0.352255
# [209]	train-rmse:0.424407	eval-rmse:0.460719	train-rmspe:0.344952	eval-rmspe:0.349428
# [210]	train-rmse:0.4197	eval-rmse:0.455943	train-rmspe:0.342402	eval-rmspe:0.346555
# [211]	train-rmse:0.415341	eval-rmse:0.451425	train-rmspe:0.340063	eval-rmspe:0.34383
# [212]	train-rmse:0.411115	eval-rmse:0.447032	train-rmspe:0.337801	eval-rmspe:0.341159
# [213]	train-rmse:0.406718	eval-rmse:0.442612	train-rmspe:0.335445	eval-rmspe:0.338474
# [214]	train-rmse:0.402227	eval-rmse:0.438143	train-rmspe:0.332951	eval-rmspe:0.335787
# [215]	train-rmse:0.397771	eval-rmse:0.433647	train-rmspe:0.330402	eval-rmspe:0.333057
# [216]	train-rmse:0.393558	eval-rmse:0.429419	train-rmspe:0.328035	eval-rmspe:0.330482
# [217]	train-rmse:0.389725	eval-rmse:0.425511	train-rmspe:0.325975	eval-rmspe:0.328079
# [218]	train-rmse:0.3856	eval-rmse:0.421314	train-rmspe:0.323758	eval-rmspe:0.325534
# [219]	train-rmse:0.381611	eval-rmse:0.417239	train-rmspe:0.321603	eval-rmspe:0.323034
# [220]	train-rmse:0.377955	eval-rmse:0.413385	train-rmspe:0.319668	eval-rmspe:0.320663
# [221]	train-rmse:0.373967	eval-rmse:0.40934	train-rmspe:0.317517	eval-rmspe:0.318215
# [222]	train-rmse:0.370246	eval-rmse:0.405612	train-rmspe:0.315506	eval-rmspe:0.315891
# [223]	train-rmse:0.366753	eval-rmse:0.401945	train-rmspe:0.313662	eval-rmspe:0.313625
# [224]	train-rmse:0.363232	eval-rmse:0.398242	train-rmspe:0.311794	eval-rmspe:0.311357
# [225]	train-rmse:0.359807	eval-rmse:0.394766	train-rmspe:0.309995	eval-rmspe:0.309211
# [226]	train-rmse:0.356437	eval-rmse:0.391272	train-rmspe:0.308274	eval-rmspe:0.307065
# [227]	train-rmse:0.352998	eval-rmse:0.387743	train-rmspe:0.306457	eval-rmspe:0.304878
# [228]	train-rmse:0.349878	eval-rmse:0.384527	train-rmspe:0.304851	eval-rmspe:0.3029
# [229]	train-rmse:0.346762	eval-rmse:0.38131	train-rmspe:0.303092	eval-rmspe:0.300924
# [230]	train-rmse:0.343748	eval-rmse:0.378085	train-rmspe:0.301541	eval-rmspe:0.298957
# [231]	train-rmse:0.340753	eval-rmse:0.374972	train-rmspe:0.300034	eval-rmspe:0.297052
# [232]	train-rmse:0.337742	eval-rmse:0.371891	train-rmspe:0.298441	eval-rmspe:0.295133
# [233]	train-rmse:0.33471	eval-rmse:0.368884	train-rmspe:0.296897	eval-rmspe:0.293305
# [234]	train-rmse:0.331736	eval-rmse:0.365766	train-rmspe:0.295278	eval-rmspe:0.291398
# [235]	train-rmse:0.328937	eval-rmse:0.36284	train-rmspe:0.293897	eval-rmspe:0.289614
# [236]	train-rmse:0.326203	eval-rmse:0.360016	train-rmspe:0.292534	eval-rmspe:0.287886
# [237]	train-rmse:0.323164	eval-rmse:0.357079	train-rmspe:0.290966	eval-rmspe:0.286106
# [238]	train-rmse:0.320498	eval-rmse:0.354345	train-rmspe:0.289563	eval-rmspe:0.28444
# [239]	train-rmse:0.317065	eval-rmse:0.350968	train-rmspe:0.287688	eval-rmspe:0.282388
# [240]	train-rmse:0.314593	eval-rmse:0.348383	train-rmspe:0.286492	eval-rmspe:0.280807
# [241]	train-rmse:0.312192	eval-rmse:0.345933	train-rmspe:0.285346	eval-rmspe:0.279329
# [242]	train-rmse:0.309462	eval-rmse:0.343219	train-rmspe:0.283945	eval-rmspe:0.277654
# [243]	train-rmse:0.307096	eval-rmse:0.340803	train-rmspe:0.282829	eval-rmspe:0.276196
# [244]	train-rmse:0.304231	eval-rmse:0.337968	train-rmspe:0.281386	eval-rmspe:0.274473
# [245]	train-rmse:0.30162	eval-rmse:0.335326	train-rmspe:0.280053	eval-rmspe:0.272794
# [246]	train-rmse:0.298992	eval-rmse:0.332673	train-rmspe:0.27869	eval-rmspe:0.271086
# [247]	train-rmse:0.296691	eval-rmse:0.330305	train-rmspe:0.277496	eval-rmspe:0.269633
# [248]	train-rmse:0.29461	eval-rmse:0.32809	train-rmspe:0.276538	eval-rmspe:0.268301
# [249]	train-rmse:0.29259	eval-rmse:0.325991	train-rmspe:0.275615	eval-rmspe:0.267034
# [250]	train-rmse:0.290605	eval-rmse:0.323761	train-rmspe:0.274726	eval-rmspe:0.26573
# [251]	train-rmse:0.288667	eval-rmse:0.321658	train-rmspe:0.27383	eval-rmspe:0.264467
# [252]	train-rmse:0.286582	eval-rmse:0.319586	train-rmspe:0.272785	eval-rmspe:0.263235
# [253]	train-rmse:0.284212	eval-rmse:0.317235	train-rmspe:0.271656	eval-rmspe:0.261711
# [254]	train-rmse:0.282365	eval-rmse:0.315336	train-rmspe:0.270865	eval-rmspe:0.260588
# [255]	train-rmse:0.28042	eval-rmse:0.313271	train-rmspe:0.270005	eval-rmspe:0.259348
# [256]	train-rmse:0.277936	eval-rmse:0.310754	train-rmspe:0.268729	eval-rmspe:0.257721
# [257]	train-rmse:0.276141	eval-rmse:0.308904	train-rmspe:0.267975	eval-rmspe:0.256655
# [258]	train-rmse:0.274245	eval-rmse:0.306949	train-rmspe:0.267039	eval-rmspe:0.255476
# [259]	train-rmse:0.272623	eval-rmse:0.305205	train-rmspe:0.266393	eval-rmspe:0.254474
# [260]	train-rmse:0.270787	eval-rmse:0.303339	train-rmspe:0.265403	eval-rmspe:0.253376
# [261]	train-rmse:0.26913	eval-rmse:0.301622	train-rmspe:0.264675	eval-rmspe:0.252399
# [262]	train-rmse:0.267573	eval-rmse:0.300023	train-rmspe:0.264063	eval-rmspe:0.251499
# [263]	train-rmse:0.265743	eval-rmse:0.298355	train-rmspe:0.26316	eval-rmspe:0.250543
# [264]	train-rmse:0.264027	eval-rmse:0.296621	train-rmspe:0.262384	eval-rmspe:0.249501
# [265]	train-rmse:0.262391	eval-rmse:0.294991	train-rmspe:0.261707	eval-rmspe:0.248531
# [266]	train-rmse:0.260701	eval-rmse:0.293253	train-rmspe:0.260942	eval-rmspe:0.247535
# [267]	train-rmse:0.258497	eval-rmse:0.291073	train-rmspe:0.259696	eval-rmspe:0.246119
# [268]	train-rmse:0.256448	eval-rmse:0.289056	train-rmspe:0.258665	eval-rmspe:0.244846
# [269]	train-rmse:0.255112	eval-rmse:0.287615	train-rmspe:0.258159	eval-rmspe:0.244058
# [270]	train-rmse:0.253305	eval-rmse:0.285772	train-rmspe:0.257313	eval-rmspe:0.242929
# [271]	train-rmse:0.251859	eval-rmse:0.284333	train-rmspe:0.256718	eval-rmspe:0.242125
# [272]	train-rmse:0.250074	eval-rmse:0.282593	train-rmspe:0.255695	eval-rmspe:0.24101
# [273]	train-rmse:0.248728	eval-rmse:0.281174	train-rmspe:0.255061	eval-rmspe:0.240197
# [274]	train-rmse:0.247451	eval-rmse:0.279872	train-rmspe:0.254597	eval-rmspe:0.239491
# [275]	train-rmse:0.245786	eval-rmse:0.278223	train-rmspe:0.253867	eval-rmspe:0.238461
# [276]	train-rmse:0.243918	eval-rmse:0.276369	train-rmspe:0.252923	eval-rmspe:0.237301
# [277]	train-rmse:0.242378	eval-rmse:0.274817	train-rmspe:0.25204	eval-rmspe:0.236334
# [278]	train-rmse:0.240973	eval-rmse:0.273427	train-rmspe:0.251481	eval-rmspe:0.23549
# [279]	train-rmse:0.239916	eval-rmse:0.272231	train-rmspe:0.251145	eval-rmspe:0.234899
# [280]	train-rmse:0.238494	eval-rmse:0.27084	train-rmspe:0.250461	eval-rmspe:0.234117
# [281]	train-rmse:0.237096	eval-rmse:0.269436	train-rmspe:0.249802	eval-rmspe:0.233304
# [282]	train-rmse:0.236086	eval-rmse:0.26829	train-rmspe:0.249519	eval-rmspe:0.23274
# [283]	train-rmse:0.235131	eval-rmse:0.267181	train-rmspe:0.249216	eval-rmspe:0.232207
# [284]	train-rmse:0.234166	eval-rmse:0.266109	train-rmspe:0.248877	eval-rmspe:0.231654
# [285]	train-rmse:0.23285	eval-rmse:0.264811	train-rmspe:0.248264	eval-rmspe:0.230892
# [286]	train-rmse:0.231964	eval-rmse:0.263858	train-rmspe:0.248023	eval-rmspe:0.230423
# [287]	train-rmse:0.230939	eval-rmse:0.262713	train-rmspe:0.24769	eval-rmspe:0.229831
# [288]	train-rmse:0.229918	eval-rmse:0.261581	train-rmspe:0.247352	eval-rmspe:0.229266
# [289]	train-rmse:0.228346	eval-rmse:0.259885	train-rmspe:0.246603	eval-rmspe:0.228173
# [290]	train-rmse:0.227047	eval-rmse:0.258619	train-rmspe:0.246027	eval-rmspe:0.227351
# [291]	train-rmse:0.226235	eval-rmse:0.25767	train-rmspe:0.245834	eval-rmspe:0.226887
# [292]	train-rmse:0.225038	eval-rmse:0.256521	train-rmspe:0.2453	eval-rmspe:0.226152
# [293]	train-rmse:0.223864	eval-rmse:0.255401	train-rmspe:0.24479	eval-rmspe:0.225438
# [294]	train-rmse:0.222429	eval-rmse:0.253965	train-rmspe:0.244003	eval-rmspe:0.224537
# [295]	train-rmse:0.221376	eval-rmse:0.253082	train-rmspe:0.243598	eval-rmspe:0.224063
# [296]	train-rmse:0.2202	eval-rmse:0.25193	train-rmspe:0.242991	eval-rmspe:0.223349
# [297]	train-rmse:0.219397	eval-rmse:0.251085	train-rmspe:0.242699	eval-rmspe:0.222966
# [298]	train-rmse:0.2187	eval-rmse:0.250328	train-rmspe:0.242509	eval-rmspe:0.222664
# [299]	train-rmse:0.217795	eval-rmse:0.249373	train-rmspe:0.242164	eval-rmspe:0.222092
# [300]	train-rmse:0.216916	eval-rmse:0.248537	train-rmspe:0.241762	eval-rmspe:0.22172
# [301]	train-rmse:0.216034	eval-rmse:0.247751	train-rmspe:0.241443	eval-rmspe:0.221361
# [302]	train-rmse:0.214906	eval-rmse:0.246586	train-rmspe:0.24088	eval-rmspe:0.220616
# [303]	train-rmse:0.214259	eval-rmse:0.245874	train-rmspe:0.240714	eval-rmspe:0.22028
# [304]	train-rmse:0.213614	eval-rmse:0.245222	train-rmspe:0.240491	eval-rmspe:0.220044
# [305]	train-rmse:0.213036	eval-rmse:0.244611	train-rmspe:0.240407	eval-rmspe:0.219811
# [306]	train-rmse:0.211987	eval-rmse:0.243594	train-rmspe:0.239882	eval-rmspe:0.219128
# [307]	train-rmse:0.210995	eval-rmse:0.242638	train-rmspe:0.239482	eval-rmspe:0.218546
# [308]	train-rmse:0.20997	eval-rmse:0.24157	train-rmspe:0.23898	eval-rmspe:0.217865
# [309]	train-rmse:0.208868	eval-rmse:0.240464	train-rmspe:0.238325	eval-rmspe:0.217114
# [310]	train-rmse:0.208176	eval-rmse:0.239715	train-rmspe:0.23815	eval-rmspe:0.216763
# [311]	train-rmse:0.207121	eval-rmse:0.238721	train-rmspe:0.237607	eval-rmspe:0.216161
# [312]	train-rmse:0.206104	eval-rmse:0.237722	train-rmspe:0.237063	eval-rmspe:0.21554
# [313]	train-rmse:0.205586	eval-rmse:0.237208	train-rmspe:0.23694	eval-rmspe:0.215365
# [314]	train-rmse:0.204731	eval-rmse:0.2364	train-rmspe:0.236465	eval-rmspe:0.214854
# [315]	train-rmse:0.203739	eval-rmse:0.235371	train-rmspe:0.235896	eval-rmspe:0.214161
# [316]	train-rmse:0.20308	eval-rmse:0.234693	train-rmspe:0.235733	eval-rmspe:0.213788
# [317]	train-rmse:0.202394	eval-rmse:0.234038	train-rmspe:0.23549	eval-rmspe:0.213443
# [318]	train-rmse:0.201869	eval-rmse:0.233553	train-rmspe:0.235383	eval-rmspe:0.213274
# [319]	train-rmse:0.20117	eval-rmse:0.232782	train-rmspe:0.235158	eval-rmspe:0.21284
# [320]	train-rmse:0.200606	eval-rmse:0.232172	train-rmspe:0.234974	eval-rmspe:0.212582
# [321]	train-rmse:0.199716	eval-rmse:0.231346	train-rmspe:0.234631	eval-rmspe:0.212034
# [322]	train-rmse:0.198991	eval-rmse:0.230669	train-rmspe:0.23426	eval-rmspe:0.211664
# [323]	train-rmse:0.198363	eval-rmse:0.230068	train-rmspe:0.234072	eval-rmspe:0.211336
# [324]	train-rmse:0.197873	eval-rmse:0.229607	train-rmspe:0.233895	eval-rmspe:0.211156
# [325]	train-rmse:0.196871	eval-rmse:0.228731	train-rmspe:0.233369	eval-rmspe:0.210623
# [326]	train-rmse:0.196144	eval-rmse:0.227919	train-rmspe:0.233066	eval-rmspe:0.210101
# [327]	train-rmse:0.194765	eval-rmse:0.22667	train-rmspe:0.232195	eval-rmspe:0.209172
# [328]	train-rmse:0.194053	eval-rmse:0.226241	train-rmspe:0.231878	eval-rmspe:0.209014
# [329]	train-rmse:0.193695	eval-rmse:0.225869	train-rmspe:0.231867	eval-rmspe:0.208932
# [330]	train-rmse:0.193226	eval-rmse:0.225445	train-rmspe:0.231674	eval-rmspe:0.208798
# [331]	train-rmse:0.192681	eval-rmse:0.22499	train-rmspe:0.231489	eval-rmspe:0.208606
# [332]	train-rmse:0.191934	eval-rmse:0.224311	train-rmspe:0.231108	eval-rmspe:0.208217
# [333]	train-rmse:0.191593	eval-rmse:0.223961	train-rmspe:0.230971	eval-rmspe:0.208106
# [334]	train-rmse:0.191217	eval-rmse:0.223637	train-rmspe:0.23084	eval-rmspe:0.208027
# [335]	train-rmse:0.190679	eval-rmse:0.223089	train-rmspe:0.230647	eval-rmspe:0.207727
# [336]	train-rmse:0.190275	eval-rmse:0.222631	train-rmspe:0.230509	eval-rmspe:0.207518
# [337]	train-rmse:0.189866	eval-rmse:0.222277	train-rmspe:0.230345	eval-rmspe:0.207405
# [338]	train-rmse:0.189488	eval-rmse:0.22189	train-rmspe:0.230266	eval-rmspe:0.207266
# [339]	train-rmse:0.18839	eval-rmse:0.220892	train-rmspe:0.229558	eval-rmspe:0.206521
# [340]	train-rmse:0.188101	eval-rmse:0.22052	train-rmspe:0.229539	eval-rmspe:0.206407
# [341]	train-rmse:0.187529	eval-rmse:0.219987	train-rmspe:0.229273	eval-rmspe:0.206135
# [342]	train-rmse:0.186936	eval-rmse:0.219521	train-rmspe:0.228978	eval-rmspe:0.205891
# [343]	train-rmse:0.186447	eval-rmse:0.219076	train-rmspe:0.228807	eval-rmspe:0.205668
# [344]	train-rmse:0.185888	eval-rmse:0.218492	train-rmspe:0.228543	eval-rmspe:0.20532
# [345]	train-rmse:0.185298	eval-rmse:0.218147	train-rmspe:0.228109	eval-rmspe:0.205203
# [346]	train-rmse:0.184078	eval-rmse:0.217024	train-rmspe:0.227265	eval-rmspe:0.204319
# [347]	train-rmse:0.183441	eval-rmse:0.21647	train-rmspe:0.226929	eval-rmspe:0.203988
# [348]	train-rmse:0.182244	eval-rmse:0.215348	train-rmspe:0.226138	eval-rmspe:0.203122
# [349]	train-rmse:0.182012	eval-rmse:0.215111	train-rmspe:0.226149	eval-rmspe:0.203069
# [350]	train-rmse:0.181573	eval-rmse:0.214769	train-rmspe:0.225994	eval-rmspe:0.202941
# [351]	train-rmse:0.181274	eval-rmse:0.214493	train-rmspe:0.225838	eval-rmspe:0.202865
# [352]	train-rmse:0.181007	eval-rmse:0.214215	train-rmspe:0.22572	eval-rmspe:0.202787
# [353]	train-rmse:0.180367	eval-rmse:0.213507	train-rmspe:0.225357	eval-rmspe:0.202285
# [354]	train-rmse:0.179451	eval-rmse:0.212578	train-rmspe:0.224808	eval-rmspe:0.20153
# [355]	train-rmse:0.178759	eval-rmse:0.211998	train-rmspe:0.224373	eval-rmspe:0.20112
# [356]	train-rmse:0.178451	eval-rmse:0.211693	train-rmspe:0.224234	eval-rmspe:0.201004
# [357]	train-rmse:0.177675	eval-rmse:0.210921	train-rmspe:0.223772	eval-rmspe:0.200458
# [358]	train-rmse:0.177032	eval-rmse:0.210312	train-rmspe:0.223345	eval-rmspe:0.200021
# [359]	train-rmse:0.176804	eval-rmse:0.21009	train-rmspe:0.223292	eval-rmspe:0.199949
# [360]	train-rmse:0.175876	eval-rmse:0.209227	train-rmspe:0.222745	eval-rmspe:0.199312
# [361]	train-rmse:0.175438	eval-rmse:0.208997	train-rmspe:0.222556	eval-rmspe:0.199244
# [362]	train-rmse:0.174505	eval-rmse:0.208117	train-rmspe:0.222006	eval-rmspe:0.198553
# [363]	train-rmse:0.173533	eval-rmse:0.207268	train-rmspe:0.221272	eval-rmspe:0.197867
# [364]	train-rmse:0.172904	eval-rmse:0.206686	train-rmspe:0.220898	eval-rmspe:0.197461
# [365]	train-rmse:0.172573	eval-rmse:0.206411	train-rmspe:0.220772	eval-rmspe:0.197329
# [366]	train-rmse:0.172143	eval-rmse:0.205953	train-rmspe:0.220496	eval-rmspe:0.197044
# [367]	train-rmse:0.171845	eval-rmse:0.205725	train-rmspe:0.220432	eval-rmspe:0.196957
# [368]	train-rmse:0.171575	eval-rmse:0.20547	train-rmspe:0.220298	eval-rmspe:0.196874
# [369]	train-rmse:0.171392	eval-rmse:0.205291	train-rmspe:0.220299	eval-rmspe:0.196857
# [370]	train-rmse:0.171165	eval-rmse:0.205015	train-rmspe:0.220247	eval-rmspe:0.196757
# [371]	train-rmse:0.170576	eval-rmse:0.204449	train-rmspe:0.219844	eval-rmspe:0.196306
# [372]	train-rmse:0.169935	eval-rmse:0.203887	train-rmspe:0.219323	eval-rmspe:0.195883
# [373]	train-rmse:0.1697	eval-rmse:0.20368	train-rmspe:0.219235	eval-rmspe:0.195839
# [374]	train-rmse:0.168777	eval-rmse:0.202929	train-rmspe:0.218663	eval-rmspe:0.195271
# [375]	train-rmse:0.168298	eval-rmse:0.202545	train-rmspe:0.218402	eval-rmspe:0.195042
# [376]	train-rmse:0.16772	eval-rmse:0.202012	train-rmspe:0.218046	eval-rmspe:0.194651
# [377]	train-rmse:0.167178	eval-rmse:0.201501	train-rmspe:0.217739	eval-rmspe:0.1943
# [378]	train-rmse:0.166614	eval-rmse:0.200742	train-rmspe:0.217416	eval-rmspe:0.193687
# [379]	train-rmse:0.165775	eval-rmse:0.200018	train-rmspe:0.216855	eval-rmspe:0.1931
# [380]	train-rmse:0.16534	eval-rmse:0.199471	train-rmspe:0.216635	eval-rmspe:0.192697
# [381]	train-rmse:0.165128	eval-rmse:0.199296	train-rmspe:0.216581	eval-rmspe:0.192646
# [382]	train-rmse:0.164925	eval-rmse:0.199125	train-rmspe:0.216444	eval-rmspe:0.192587
# [383]	train-rmse:0.164395	eval-rmse:0.198654	train-rmspe:0.21614	eval-rmspe:0.192236
# [384]	train-rmse:0.164232	eval-rmse:0.198527	train-rmspe:0.216063	eval-rmspe:0.192222
# [385]	train-rmse:0.164031	eval-rmse:0.198401	train-rmspe:0.215944	eval-rmspe:0.192223
# [386]	train-rmse:0.163896	eval-rmse:0.19827	train-rmspe:0.215938	eval-rmspe:0.192222
# [387]	train-rmse:0.163476	eval-rmse:0.198038	train-rmspe:0.215737	eval-rmspe:0.192111
# [388]	train-rmse:0.162913	eval-rmse:0.197569	train-rmspe:0.215374	eval-rmspe:0.191758
# [389]	train-rmse:0.162608	eval-rmse:0.197442	train-rmspe:0.21521	eval-rmspe:0.191742
# [390]	train-rmse:0.162148	eval-rmse:0.197015	train-rmspe:0.214933	eval-rmspe:0.191406
# [391]	train-rmse:0.162004	eval-rmse:0.196891	train-rmspe:0.214878	eval-rmspe:0.191384
# [392]	train-rmse:0.161446	eval-rmse:0.196369	train-rmspe:0.21451	eval-rmspe:0.190984
# [393]	train-rmse:0.161152	eval-rmse:0.196106	train-rmspe:0.2143	eval-rmspe:0.190828
# [394]	train-rmse:0.1606	eval-rmse:0.195652	train-rmspe:0.213914	eval-rmspe:0.190506
# [395]	train-rmse:0.160459	eval-rmse:0.195506	train-rmspe:0.213856	eval-rmspe:0.190479
# [396]	train-rmse:0.160124	eval-rmse:0.195178	train-rmspe:0.213613	eval-rmspe:0.190234
# [397]	train-rmse:0.159911	eval-rmse:0.194995	train-rmspe:0.213396	eval-rmspe:0.190152
# [398]	train-rmse:0.159755	eval-rmse:0.194878	train-rmspe:0.213292	eval-rmspe:0.190167
# [399]	train-rmse:0.159643	eval-rmse:0.194779	train-rmspe:0.213255	eval-rmspe:0.19015
# [400]	train-rmse:0.159287	eval-rmse:0.194464	train-rmspe:0.213041	eval-rmspe:0.189917
# [401]	train-rmse:0.159154	eval-rmse:0.194351	train-rmspe:0.212991	eval-rmspe:0.18991
# [402]	train-rmse:0.158996	eval-rmse:0.194203	train-rmspe:0.21293	eval-rmspe:0.189856
# [403]	train-rmse:0.158541	eval-rmse:0.193743	train-rmspe:0.212628	eval-rmspe:0.189518
# [404]	train-rmse:0.158194	eval-rmse:0.193402	train-rmspe:0.212441	eval-rmspe:0.189273
# [405]	train-rmse:0.157727	eval-rmse:0.193004	train-rmspe:0.212168	eval-rmspe:0.188999
# [406]	train-rmse:0.156936	eval-rmse:0.192303	train-rmspe:0.211621	eval-rmspe:0.188372
# [407]	train-rmse:0.156729	eval-rmse:0.192155	train-rmspe:0.211526	eval-rmspe:0.188316
# [408]	train-rmse:0.156589	eval-rmse:0.192043	train-rmspe:0.211367	eval-rmspe:0.188267
# [409]	train-rmse:0.156048	eval-rmse:0.191565	train-rmspe:0.211006	eval-rmspe:0.18788
# [410]	train-rmse:0.155719	eval-rmse:0.191258	train-rmspe:0.210731	eval-rmspe:0.187645
# [411]	train-rmse:0.155171	eval-rmse:0.19081	train-rmspe:0.210361	eval-rmspe:0.187284
# [412]	train-rmse:0.155069	eval-rmse:0.190765	train-rmspe:0.210317	eval-rmspe:0.187308
# [413]	train-rmse:0.154593	eval-rmse:0.190348	train-rmspe:0.209968	eval-rmspe:0.186936
# [414]	train-rmse:0.154415	eval-rmse:0.190161	train-rmspe:0.209877	eval-rmspe:0.186824
# [415]	train-rmse:0.154101	eval-rmse:0.189834	train-rmspe:0.209614	eval-rmspe:0.186567
# [416]	train-rmse:0.154005	eval-rmse:0.18974	train-rmspe:0.209569	eval-rmspe:0.186561
# [417]	train-rmse:0.153762	eval-rmse:0.189519	train-rmspe:0.20936	eval-rmspe:0.186399
# [418]	train-rmse:0.153646	eval-rmse:0.189397	train-rmspe:0.209332	eval-rmspe:0.186359
# [419]	train-rmse:0.153393	eval-rmse:0.189195	train-rmspe:0.209129	eval-rmspe:0.186222
# [420]	train-rmse:0.153229	eval-rmse:0.189089	train-rmspe:0.208893	eval-rmspe:0.186189
# [421]	train-rmse:0.152903	eval-rmse:0.188726	train-rmspe:0.208709	eval-rmspe:0.18591
# [422]	train-rmse:0.152756	eval-rmse:0.188592	train-rmspe:0.208649	eval-rmspe:0.185847
# [423]	train-rmse:0.152569	eval-rmse:0.188406	train-rmspe:0.208498	eval-rmspe:0.185723
# [424]	train-rmse:0.152221	eval-rmse:0.188114	train-rmspe:0.208274	eval-rmspe:0.185507
# [425]	train-rmse:0.15183	eval-rmse:0.187751	train-rmspe:0.207992	eval-rmspe:0.185203
# [426]	train-rmse:0.151665	eval-rmse:0.187632	train-rmspe:0.207916	eval-rmspe:0.185146
# [427]	train-rmse:0.151522	eval-rmse:0.187503	train-rmspe:0.207858	eval-rmspe:0.185076
# [428]	train-rmse:0.151403	eval-rmse:0.187425	train-rmspe:0.207742	eval-rmspe:0.185049
# [429]	train-rmse:0.151094	eval-rmse:0.187182	train-rmspe:0.207549	eval-rmspe:0.184868
# [430]	train-rmse:0.150789	eval-rmse:0.186895	train-rmspe:0.207363	eval-rmspe:0.184639
# [431]	train-rmse:0.150563	eval-rmse:0.186789	train-rmspe:0.207176	eval-rmspe:0.184609
# [432]	train-rmse:0.150261	eval-rmse:0.186541	train-rmspe:0.207018	eval-rmspe:0.184412
# [433]	train-rmse:0.150166	eval-rmse:0.186459	train-rmspe:0.206904	eval-rmspe:0.184407
# [434]	train-rmse:0.150092	eval-rmse:0.186431	train-rmspe:0.206877	eval-rmspe:0.184435
# [435]	train-rmse:0.149856	eval-rmse:0.186239	train-rmspe:0.206729	eval-rmspe:0.184288
# [436]	train-rmse:0.149678	eval-rmse:0.186081	train-rmspe:0.206588	eval-rmspe:0.184174
# [437]	train-rmse:0.149522	eval-rmse:0.185965	train-rmspe:0.206478	eval-rmspe:0.18413
# [438]	train-rmse:0.149279	eval-rmse:0.185753	train-rmspe:0.206315	eval-rmspe:0.183963
# [439]	train-rmse:0.14902	eval-rmse:0.1855	train-rmspe:0.206156	eval-rmspe:0.18376
# [440]	train-rmse:0.148918	eval-rmse:0.185456	train-rmspe:0.206007	eval-rmspe:0.183758
# [441]	train-rmse:0.148585	eval-rmse:0.185213	train-rmspe:0.20588	eval-rmspe:0.183571
# [442]	train-rmse:0.148482	eval-rmse:0.185175	train-rmspe:0.205842	eval-rmspe:0.18357
# [443]	train-rmse:0.148232	eval-rmse:0.184947	train-rmspe:0.205698	eval-rmspe:0.18339
# [444]	train-rmse:0.147953	eval-rmse:0.184733	train-rmspe:0.205505	eval-rmspe:0.183236
# [445]	train-rmse:0.147871	eval-rmse:0.184676	train-rmspe:0.205421	eval-rmspe:0.183238
# [446]	train-rmse:0.147643	eval-rmse:0.18447	train-rmspe:0.205209	eval-rmspe:0.183081
# [447]	train-rmse:0.147257	eval-rmse:0.184114	train-rmspe:0.20492	eval-rmspe:0.182745
# [448]	train-rmse:0.146959	eval-rmse:0.183853	train-rmspe:0.204721	eval-rmspe:0.18253
# [449]	train-rmse:0.146669	eval-rmse:0.183565	train-rmspe:0.204514	eval-rmspe:0.182264
# [450]	train-rmse:0.146203	eval-rmse:0.183114	train-rmspe:0.204177	eval-rmspe:0.181864
# [451]	train-rmse:0.145943	eval-rmse:0.182903	train-rmspe:0.204014	eval-rmspe:0.181704
# [452]	train-rmse:0.145754	eval-rmse:0.182742	train-rmspe:0.203909	eval-rmspe:0.181585
# [453]	train-rmse:0.145682	eval-rmse:0.182699	train-rmspe:0.203875	eval-rmspe:0.181601
# [454]	train-rmse:0.145417	eval-rmse:0.182645	train-rmspe:0.203621	eval-rmspe:0.181583
# [455]	train-rmse:0.145348	eval-rmse:0.182623	train-rmspe:0.203579	eval-rmspe:0.181603
# [456]	train-rmse:0.144895	eval-rmse:0.182263	train-rmspe:0.203199	eval-rmspe:0.18125
# [457]	train-rmse:0.144317	eval-rmse:0.181736	train-rmspe:0.202755	eval-rmspe:0.180784
# [458]	train-rmse:0.144043	eval-rmse:0.181458	train-rmspe:0.202528	eval-rmspe:0.180546
# [459]	train-rmse:0.143827	eval-rmse:0.18126	train-rmspe:0.202396	eval-rmspe:0.180382
# [460]	train-rmse:0.14373	eval-rmse:0.181157	train-rmspe:0.202345	eval-rmspe:0.180321
# [461]	train-rmse:0.143513	eval-rmse:0.180974	train-rmspe:0.202226	eval-rmspe:0.180176
# [462]	train-rmse:0.1433	eval-rmse:0.180767	train-rmspe:0.202026	eval-rmspe:0.179992
# [463]	train-rmse:0.143108	eval-rmse:0.180608	train-rmspe:0.201919	eval-rmspe:0.179874
# [464]	train-rmse:0.142889	eval-rmse:0.180459	train-rmspe:0.201756	eval-rmspe:0.179773
# [465]	train-rmse:0.142677	eval-rmse:0.180234	train-rmspe:0.201622	eval-rmspe:0.179577
# [466]	train-rmse:0.142521	eval-rmse:0.180089	train-rmspe:0.201534	eval-rmspe:0.179454
# [467]	train-rmse:0.142248	eval-rmse:0.179854	train-rmspe:0.201382	eval-rmspe:0.179258
# [468]	train-rmse:0.141748	eval-rmse:0.179397	train-rmspe:0.200969	eval-rmspe:0.178846
# [469]	train-rmse:0.141535	eval-rmse:0.179281	train-rmspe:0.200797	eval-rmspe:0.178768
# [470]	train-rmse:0.141137	eval-rmse:0.178852	train-rmspe:0.200518	eval-rmspe:0.178396
# [471]	train-rmse:0.141061	eval-rmse:0.178839	train-rmspe:0.200466	eval-rmspe:0.178413
# [472]	train-rmse:0.140936	eval-rmse:0.178748	train-rmspe:0.200392	eval-rmspe:0.178342
# [473]	train-rmse:0.140762	eval-rmse:0.178637	train-rmspe:0.200227	eval-rmspe:0.178271
# [474]	train-rmse:0.140656	eval-rmse:0.178571	train-rmspe:0.20005	eval-rmspe:0.178233
# [475]	train-rmse:0.140549	eval-rmse:0.178525	train-rmspe:0.199971	eval-rmspe:0.178236
# [476]	train-rmse:0.140393	eval-rmse:0.178398	train-rmspe:0.199881	eval-rmspe:0.178136
# [477]	train-rmse:0.139977	eval-rmse:0.178005	train-rmspe:0.199578	eval-rmspe:0.177797
# [478]	train-rmse:0.139723	eval-rmse:0.177762	train-rmspe:0.199463	eval-rmspe:0.177583
# [479]	train-rmse:0.139524	eval-rmse:0.177527	train-rmspe:0.199219	eval-rmspe:0.177365
# [480]	train-rmse:0.139287	eval-rmse:0.177316	train-rmspe:0.198986	eval-rmspe:0.17718
# [481]	train-rmse:0.13911	eval-rmse:0.177144	train-rmspe:0.198831	eval-rmspe:0.17704
# [482]	train-rmse:0.13888	eval-rmse:0.17694	train-rmspe:0.198603	eval-rmspe:0.176846
# [483]	train-rmse:0.138662	eval-rmse:0.176792	train-rmspe:0.198474	eval-rmspe:0.176739
# [484]	train-rmse:0.138596	eval-rmse:0.176765	train-rmspe:0.198416	eval-rmspe:0.176738
# [485]	train-rmse:0.138388	eval-rmse:0.176568	train-rmspe:0.198264	eval-rmspe:0.176567
# [486]	train-rmse:0.138135	eval-rmse:0.176325	train-rmspe:0.198085	eval-rmspe:0.176345
# [487]	train-rmse:0.137883	eval-rmse:0.17607	train-rmspe:0.197923	eval-rmspe:0.17612
# [488]	train-rmse:0.137803	eval-rmse:0.17606	train-rmspe:0.197868	eval-rmspe:0.176148
# [489]	train-rmse:0.137651	eval-rmse:0.175934	train-rmspe:0.197809	eval-rmspe:0.176046
# [490]	train-rmse:0.137527	eval-rmse:0.175816	train-rmspe:0.197681	eval-rmspe:0.175954
# [491]	train-rmse:0.13723	eval-rmse:0.175549	train-rmspe:0.197527	eval-rmspe:0.175725
# [492]	train-rmse:0.137159	eval-rmse:0.175564	train-rmspe:0.197432	eval-rmspe:0.17577
# [493]	train-rmse:0.137025	eval-rmse:0.175436	train-rmspe:0.197302	eval-rmspe:0.175654
# [494]	train-rmse:0.136965	eval-rmse:0.175354	train-rmspe:0.197308	eval-rmspe:0.1756
# [495]	train-rmse:0.136795	eval-rmse:0.175202	train-rmspe:0.197229	eval-rmspe:0.175476
# [496]	train-rmse:0.136699	eval-rmse:0.175129	train-rmspe:0.197112	eval-rmspe:0.175425
# [497]	train-rmse:0.13657	eval-rmse:0.17504	train-rmspe:0.197039	eval-rmspe:0.175354
# [498]	train-rmse:0.136287	eval-rmse:0.174825	train-rmspe:0.196826	eval-rmspe:0.175179
# [499]	train-rmse:0.136157	eval-rmse:0.174682	train-rmspe:0.196735	eval-rmspe:0.175071
# [500]	train-rmse:0.135925	eval-rmse:0.174483	train-rmspe:0.196564	eval-rmspe:0.174873
# [501]	train-rmse:0.135887	eval-rmse:0.174461	train-rmspe:0.196522	eval-rmspe:0.174873
# [502]	train-rmse:0.1357	eval-rmse:0.174303	train-rmspe:0.196425	eval-rmspe:0.174731
# [503]	train-rmse:0.135601	eval-rmse:0.17419	train-rmspe:0.196377	eval-rmspe:0.174635
# [504]	train-rmse:0.135341	eval-rmse:0.173992	train-rmspe:0.196166	eval-rmspe:0.17445
# [505]	train-rmse:0.135288	eval-rmse:0.173974	train-rmspe:0.196108	eval-rmspe:0.174444
# [506]	train-rmse:0.135182	eval-rmse:0.173906	train-rmspe:0.196013	eval-rmspe:0.174389
# [507]	train-rmse:0.134856	eval-rmse:0.173654	train-rmspe:0.195708	eval-rmspe:0.174152
# [508]	train-rmse:0.134757	eval-rmse:0.173612	train-rmspe:0.195593	eval-rmspe:0.174127
# [509]	train-rmse:0.134604	eval-rmse:0.173467	train-rmspe:0.195421	eval-rmspe:0.174003
# [510]	train-rmse:0.134393	eval-rmse:0.173259	train-rmspe:0.195271	eval-rmspe:0.173806
# [511]	train-rmse:0.134338	eval-rmse:0.173258	train-rmspe:0.195235	eval-rmspe:0.173834
# [512]	train-rmse:0.134278	eval-rmse:0.173237	train-rmspe:0.195149	eval-rmspe:0.173831
# [513]	train-rmse:0.134211	eval-rmse:0.173181	train-rmspe:0.195058	eval-rmspe:0.17379
# [514]	train-rmse:0.134057	eval-rmse:0.173013	train-rmspe:0.194975	eval-rmspe:0.173643
# [515]	train-rmse:0.133829	eval-rmse:0.172792	train-rmspe:0.194833	eval-rmspe:0.173433
# [516]	train-rmse:0.133659	eval-rmse:0.17265	train-rmspe:0.194712	eval-rmspe:0.173319
# [517]	train-rmse:0.133413	eval-rmse:0.172437	train-rmspe:0.194551	eval-rmspe:0.173131
# [518]	train-rmse:0.133356	eval-rmse:0.172426	train-rmspe:0.194507	eval-rmspe:0.173126
# [519]	train-rmse:0.133167	eval-rmse:0.172267	train-rmspe:0.194395	eval-rmspe:0.172978
# [520]	train-rmse:0.133118	eval-rmse:0.172202	train-rmspe:0.194333	eval-rmspe:0.172936
# [521]	train-rmse:0.132779	eval-rmse:0.171882	train-rmspe:0.194131	eval-rmspe:0.172621
# [522]	train-rmse:0.132609	eval-rmse:0.171744	train-rmspe:0.19403	eval-rmspe:0.172505
# [523]	train-rmse:0.132547	eval-rmse:0.171737	train-rmspe:0.193973	eval-rmspe:0.172538
# [524]	train-rmse:0.132347	eval-rmse:0.171541	train-rmspe:0.193859	eval-rmspe:0.172354
# [525]	train-rmse:0.132144	eval-rmse:0.171354	train-rmspe:0.193736	eval-rmspe:0.172181
# [526]	train-rmse:0.131969	eval-rmse:0.171171	train-rmspe:0.193619	eval-rmspe:0.172014
# [527]	train-rmse:0.131693	eval-rmse:0.170954	train-rmspe:0.193441	eval-rmspe:0.171791
# [528]	train-rmse:0.131599	eval-rmse:0.170856	train-rmspe:0.193381	eval-rmspe:0.171703
# [529]	train-rmse:0.131443	eval-rmse:0.170695	train-rmspe:0.193275	eval-rmspe:0.171553
# [530]	train-rmse:0.131392	eval-rmse:0.170663	train-rmspe:0.193215	eval-rmspe:0.171526
# [531]	train-rmse:0.131174	eval-rmse:0.170438	train-rmspe:0.192989	eval-rmspe:0.171291
# [532]	train-rmse:0.131008	eval-rmse:0.170303	train-rmspe:0.19292	eval-rmspe:0.171174
# [533]	train-rmse:0.130854	eval-rmse:0.170172	train-rmspe:0.192807	eval-rmspe:0.171058
# [534]	train-rmse:0.130703	eval-rmse:0.170003	train-rmspe:0.19261	eval-rmspe:0.170915
# [535]	train-rmse:0.130499	eval-rmse:0.169842	train-rmspe:0.192482	eval-rmspe:0.170772
# [536]	train-rmse:0.130145	eval-rmse:0.16953	train-rmspe:0.192157	eval-rmspe:0.170452
# [537]	train-rmse:0.129869	eval-rmse:0.169291	train-rmspe:0.191961	eval-rmspe:0.170246
# [538]	train-rmse:0.129693	eval-rmse:0.169124	train-rmspe:0.191828	eval-rmspe:0.170096
# [539]	train-rmse:0.129551	eval-rmse:0.169017	train-rmspe:0.191722	eval-rmspe:0.170021
# [540]	train-rmse:0.129388	eval-rmse:0.168848	train-rmspe:0.191622	eval-rmspe:0.169867
# [541]	train-rmse:0.129259	eval-rmse:0.1687	train-rmspe:0.191535	eval-rmspe:0.169732
# [542]	train-rmse:0.129185	eval-rmse:0.168615	train-rmspe:0.191504	eval-rmspe:0.169661
# [543]	train-rmse:0.128996	eval-rmse:0.168419	train-rmspe:0.191356	eval-rmspe:0.169482
# [544]	train-rmse:0.128948	eval-rmse:0.168391	train-rmspe:0.191295	eval-rmspe:0.169465
# [545]	train-rmse:0.12875	eval-rmse:0.168247	train-rmspe:0.191097	eval-rmspe:0.169321
# [546]	train-rmse:0.128676	eval-rmse:0.168186	train-rmspe:0.190976	eval-rmspe:0.169271
# [547]	train-rmse:0.128629	eval-rmse:0.168156	train-rmspe:0.190909	eval-rmspe:0.169251
# [548]	train-rmse:0.128583	eval-rmse:0.16813	train-rmspe:0.190861	eval-rmspe:0.169234
# [549]	train-rmse:0.128537	eval-rmse:0.168106	train-rmspe:0.190829	eval-rmspe:0.169229
# [550]	train-rmse:0.1282	eval-rmse:0.167796	train-rmspe:0.190532	eval-rmspe:0.168925
# [551]	train-rmse:0.128002	eval-rmse:0.1676	train-rmspe:0.190389	eval-rmspe:0.168753
# [552]	train-rmse:0.127777	eval-rmse:0.167411	train-rmspe:0.190206	eval-rmspe:0.168557
# [553]	train-rmse:0.127683	eval-rmse:0.167321	train-rmspe:0.190143	eval-rmspe:0.168484
# [554]	train-rmse:0.1276	eval-rmse:0.167252	train-rmspe:0.190078	eval-rmspe:0.168428
# [555]	train-rmse:0.127544	eval-rmse:0.167244	train-rmspe:0.190009	eval-rmspe:0.168435
# [556]	train-rmse:0.127316	eval-rmse:0.167075	train-rmspe:0.18982	eval-rmspe:0.168267
# [557]	train-rmse:0.127109	eval-rmse:0.166916	train-rmspe:0.189663	eval-rmspe:0.168114
# [558]	train-rmse:0.126959	eval-rmse:0.166753	train-rmspe:0.189561	eval-rmspe:0.167958
# [559]	train-rmse:0.126818	eval-rmse:0.166647	train-rmspe:0.189438	eval-rmspe:0.167864
# [560]	train-rmse:0.126743	eval-rmse:0.166598	train-rmspe:0.189389	eval-rmspe:0.167829
# [561]	train-rmse:0.126602	eval-rmse:0.166467	train-rmspe:0.189275	eval-rmspe:0.167712
# [562]	train-rmse:0.12654	eval-rmse:0.166443	train-rmspe:0.189182	eval-rmspe:0.167691
# ...
# [9816]	train-rmse:0.081457	eval-rmse:0.135797	train-rmspe:0.130496	eval-rmspe:0.137461
# [9817]	train-rmse:0.081456	eval-rmse:0.135797	train-rmspe:0.130495	eval-rmspe:0.137461
# [9818]	train-rmse:0.081456	eval-rmse:0.135797	train-rmspe:0.130494	eval-rmspe:0.137461
# [9819]	train-rmse:0.081455	eval-rmse:0.135796	train-rmspe:0.130491	eval-rmspe:0.137461
# [9820]	train-rmse:0.081455	eval-rmse:0.135796	train-rmspe:0.130491	eval-rmspe:0.137461
# [9821]	train-rmse:0.081455	eval-rmse:0.135796	train-rmspe:0.13049	eval-rmspe:0.137461
# [9822]	train-rmse:0.081454	eval-rmse:0.135796	train-rmspe:0.130488	eval-rmspe:0.13746
# [9823]	train-rmse:0.081453	eval-rmse:0.135795	train-rmspe:0.130483	eval-rmspe:0.13746
# [9824]	train-rmse:0.081453	eval-rmse:0.135795	train-rmspe:0.130477	eval-rmspe:0.13746
# [9825]	train-rmse:0.081452	eval-rmse:0.135795	train-rmspe:0.130479	eval-rmspe:0.13746
# [9826]	train-rmse:0.081452	eval-rmse:0.135795	train-rmspe:0.130478	eval-rmspe:0.13746
# [9827]	train-rmse:0.081451	eval-rmse:0.135794	train-rmspe:0.130474	eval-rmspe:0.137459
# [9828]	train-rmse:0.081451	eval-rmse:0.135794	train-rmspe:0.130477	eval-rmspe:0.137459
# [9829]	train-rmse:0.08145	eval-rmse:0.135794	train-rmspe:0.130475	eval-rmspe:0.137459
# [9830]	train-rmse:0.08145	eval-rmse:0.135794	train-rmspe:0.130475	eval-rmspe:0.137459
# [9831]	train-rmse:0.08145	eval-rmse:0.135794	train-rmspe:0.130475	eval-rmspe:0.137458
# [9832]	train-rmse:0.081449	eval-rmse:0.135794	train-rmspe:0.130475	eval-rmspe:0.137458
# [9833]	train-rmse:0.081449	eval-rmse:0.135795	train-rmspe:0.130473	eval-rmspe:0.137459
# [9834]	train-rmse:0.081448	eval-rmse:0.135795	train-rmspe:0.13047	eval-rmspe:0.137459
# [9835]	train-rmse:0.081448	eval-rmse:0.135795	train-rmspe:0.13047	eval-rmspe:0.137458
# [9836]	train-rmse:0.081448	eval-rmse:0.135795	train-rmspe:0.130469	eval-rmspe:0.137458
# [9837]	train-rmse:0.081447	eval-rmse:0.135795	train-rmspe:0.130462	eval-rmspe:0.137458
# [9838]	train-rmse:0.081447	eval-rmse:0.135795	train-rmspe:0.13046	eval-rmspe:0.137459
# [9839]	train-rmse:0.081446	eval-rmse:0.135795	train-rmspe:0.130457	eval-rmspe:0.137459
# [9840]	train-rmse:0.081446	eval-rmse:0.135795	train-rmspe:0.130456	eval-rmspe:0.137458
# [9841]	train-rmse:0.081446	eval-rmse:0.135795	train-rmspe:0.130461	eval-rmspe:0.137458
# [9842]	train-rmse:0.081445	eval-rmse:0.135794	train-rmspe:0.13046	eval-rmspe:0.137457
# [9843]	train-rmse:0.081445	eval-rmse:0.135794	train-rmspe:0.130459	eval-rmspe:0.137457
# [9844]	train-rmse:0.081445	eval-rmse:0.135794	train-rmspe:0.130458	eval-rmspe:0.137457
# [9845]	train-rmse:0.081444	eval-rmse:0.135793	train-rmspe:0.130457	eval-rmspe:0.137457
# [9846]	train-rmse:0.081444	eval-rmse:0.135794	train-rmspe:0.130452	eval-rmspe:0.137457
# [9847]	train-rmse:0.081443	eval-rmse:0.135793	train-rmspe:0.130451	eval-rmspe:0.137457
# [9848]	train-rmse:0.081443	eval-rmse:0.135793	train-rmspe:0.13045	eval-rmspe:0.137457
# [9849]	train-rmse:0.081443	eval-rmse:0.135793	train-rmspe:0.130451	eval-rmspe:0.137457
# [9850]	train-rmse:0.081442	eval-rmse:0.135792	train-rmspe:0.13045	eval-rmspe:0.137456
# [9851]	train-rmse:0.081442	eval-rmse:0.135793	train-rmspe:0.130447	eval-rmspe:0.137456
# [9852]	train-rmse:0.081441	eval-rmse:0.135793	train-rmspe:0.130445	eval-rmspe:0.137456
# [9853]	train-rmse:0.081441	eval-rmse:0.135793	train-rmspe:0.130446	eval-rmspe:0.137456
# [9854]	train-rmse:0.081441	eval-rmse:0.135792	train-rmspe:0.130443	eval-rmspe:0.137456
# [9855]	train-rmse:0.08144	eval-rmse:0.135792	train-rmspe:0.130441	eval-rmspe:0.137456
# [9856]	train-rmse:0.08144	eval-rmse:0.135793	train-rmspe:0.130436	eval-rmspe:0.137457
# [9857]	train-rmse:0.081439	eval-rmse:0.135793	train-rmspe:0.130434	eval-rmspe:0.137457
# [9858]	train-rmse:0.081439	eval-rmse:0.135793	train-rmspe:0.130434	eval-rmspe:0.137457
# [9859]	train-rmse:0.081438	eval-rmse:0.135792	train-rmspe:0.130428	eval-rmspe:0.137456
# [9860]	train-rmse:0.081438	eval-rmse:0.135793	train-rmspe:0.130426	eval-rmspe:0.137457
# [9861]	train-rmse:0.081437	eval-rmse:0.135792	train-rmspe:0.130425	eval-rmspe:0.137456
# [9862]	train-rmse:0.081437	eval-rmse:0.135793	train-rmspe:0.130424	eval-rmspe:0.137457
# [9863]	train-rmse:0.081437	eval-rmse:0.135793	train-rmspe:0.130423	eval-rmspe:0.137457
# [9864]	train-rmse:0.081436	eval-rmse:0.135794	train-rmspe:0.130422	eval-rmspe:0.137457
# [9865]	train-rmse:0.081436	eval-rmse:0.135793	train-rmspe:0.130419	eval-rmspe:0.137457
# [9866]	train-rmse:0.081435	eval-rmse:0.135793	train-rmspe:0.130421	eval-rmspe:0.137456
# [9867]	train-rmse:0.081435	eval-rmse:0.135794	train-rmspe:0.13042	eval-rmspe:0.137456
# [9868]	train-rmse:0.081434	eval-rmse:0.135793	train-rmspe:0.13042	eval-rmspe:0.137456
# [9869]	train-rmse:0.081434	eval-rmse:0.135793	train-rmspe:0.13042	eval-rmspe:0.137457
# [9870]	train-rmse:0.081433	eval-rmse:0.135793	train-rmspe:0.130421	eval-rmspe:0.137457
# [9871]	train-rmse:0.081433	eval-rmse:0.135794	train-rmspe:0.130419	eval-rmspe:0.137457
# [9872]	train-rmse:0.081433	eval-rmse:0.135793	train-rmspe:0.130421	eval-rmspe:0.137457
# [9873]	train-rmse:0.081432	eval-rmse:0.135793	train-rmspe:0.130421	eval-rmspe:0.137457
# [9874]	train-rmse:0.081432	eval-rmse:0.135793	train-rmspe:0.13042	eval-rmspe:0.137456
# [9875]	train-rmse:0.081432	eval-rmse:0.135793	train-rmspe:0.130419	eval-rmspe:0.137456
# [9876]	train-rmse:0.081431	eval-rmse:0.135793	train-rmspe:0.130416	eval-rmspe:0.137456
# [9877]	train-rmse:0.081431	eval-rmse:0.135793	train-rmspe:0.130417	eval-rmspe:0.137456
# [9878]	train-rmse:0.081431	eval-rmse:0.135794	train-rmspe:0.130415	eval-rmspe:0.137457
# [9879]	train-rmse:0.081431	eval-rmse:0.135794	train-rmspe:0.130416	eval-rmspe:0.137456
# [9880]	train-rmse:0.08143	eval-rmse:0.135794	train-rmspe:0.130412	eval-rmspe:0.137455
# [9881]	train-rmse:0.08143	eval-rmse:0.135793	train-rmspe:0.130412	eval-rmspe:0.137455
# [9882]	train-rmse:0.081429	eval-rmse:0.135793	train-rmspe:0.130412	eval-rmspe:0.137456
# [9883]	train-rmse:0.081428	eval-rmse:0.135793	train-rmspe:0.130407	eval-rmspe:0.137455
# [9884]	train-rmse:0.081428	eval-rmse:0.135792	train-rmspe:0.130408	eval-rmspe:0.137455
# [9885]	train-rmse:0.081427	eval-rmse:0.135792	train-rmspe:0.130406	eval-rmspe:0.137454
# [9886]	train-rmse:0.081427	eval-rmse:0.135792	train-rmspe:0.130406	eval-rmspe:0.137454
# [9887]	train-rmse:0.081426	eval-rmse:0.135791	train-rmspe:0.130408	eval-rmspe:0.137454
# [9888]	train-rmse:0.081426	eval-rmse:0.135791	train-rmspe:0.130407	eval-rmspe:0.137453
# [9889]	train-rmse:0.081426	eval-rmse:0.135792	train-rmspe:0.130409	eval-rmspe:0.137454
# [9890]	train-rmse:0.081425	eval-rmse:0.135792	train-rmspe:0.130409	eval-rmspe:0.137454
# [9891]	train-rmse:0.081425	eval-rmse:0.135792	train-rmspe:0.130414	eval-rmspe:0.137454
# [9892]	train-rmse:0.081425	eval-rmse:0.135792	train-rmspe:0.130413	eval-rmspe:0.137454
# [9893]	train-rmse:0.081424	eval-rmse:0.135792	train-rmspe:0.130409	eval-rmspe:0.137455
# [9894]	train-rmse:0.081424	eval-rmse:0.135792	train-rmspe:0.13041	eval-rmspe:0.137454
# [9895]	train-rmse:0.081423	eval-rmse:0.135791	train-rmspe:0.130405	eval-rmspe:0.137454
# [9896]	train-rmse:0.081423	eval-rmse:0.135791	train-rmspe:0.130404	eval-rmspe:0.137454
# [9897]	train-rmse:0.081423	eval-rmse:0.135791	train-rmspe:0.130402	eval-rmspe:0.137454
# [9898]	train-rmse:0.081422	eval-rmse:0.135791	train-rmspe:0.130399	eval-rmspe:0.137454
# [9899]	train-rmse:0.081422	eval-rmse:0.135792	train-rmspe:0.130396	eval-rmspe:0.137455
# [9900]	train-rmse:0.081421	eval-rmse:0.135791	train-rmspe:0.130396	eval-rmspe:0.137455
# [9901]	train-rmse:0.081421	eval-rmse:0.135792	train-rmspe:0.130393	eval-rmspe:0.137455
# [9902]	train-rmse:0.08142	eval-rmse:0.135792	train-rmspe:0.130391	eval-rmspe:0.137455
# [9903]	train-rmse:0.08142	eval-rmse:0.135792	train-rmspe:0.130389	eval-rmspe:0.137455
# [9904]	train-rmse:0.08142	eval-rmse:0.135792	train-rmspe:0.130389	eval-rmspe:0.137456
# [9905]	train-rmse:0.08142	eval-rmse:0.135792	train-rmspe:0.130388	eval-rmspe:0.137456
# [9906]	train-rmse:0.081419	eval-rmse:0.135791	train-rmspe:0.130387	eval-rmspe:0.137455
# [9907]	train-rmse:0.081419	eval-rmse:0.135791	train-rmspe:0.130387	eval-rmspe:0.137455
# [9908]	train-rmse:0.081418	eval-rmse:0.135791	train-rmspe:0.130386	eval-rmspe:0.137455
# [9909]	train-rmse:0.081418	eval-rmse:0.135791	train-rmspe:0.130384	eval-rmspe:0.137454
# [9910]	train-rmse:0.081418	eval-rmse:0.13579	train-rmspe:0.130384	eval-rmspe:0.137454
# [9911]	train-rmse:0.081418	eval-rmse:0.13579	train-rmspe:0.130384	eval-rmspe:0.137454
# [9912]	train-rmse:0.081417	eval-rmse:0.13579	train-rmspe:0.130384	eval-rmspe:0.137454
# [9913]	train-rmse:0.081417	eval-rmse:0.135789	train-rmspe:0.13038	eval-rmspe:0.137453
# [9914]	train-rmse:0.081416	eval-rmse:0.135789	train-rmspe:0.130379	eval-rmspe:0.137454
# [9915]	train-rmse:0.081416	eval-rmse:0.135789	train-rmspe:0.130379	eval-rmspe:0.137453
# [9916]	train-rmse:0.081416	eval-rmse:0.13579	train-rmspe:0.130378	eval-rmspe:0.137454
# [9917]	train-rmse:0.081415	eval-rmse:0.135789	train-rmspe:0.130377	eval-rmspe:0.137454
# [9918]	train-rmse:0.081415	eval-rmse:0.135789	train-rmspe:0.130375	eval-rmspe:0.137454
# [9919]	train-rmse:0.081415	eval-rmse:0.135789	train-rmspe:0.130375	eval-rmspe:0.137454
# [9920]	train-rmse:0.081414	eval-rmse:0.135789	train-rmspe:0.130371	eval-rmspe:0.137454
# [9921]	train-rmse:0.081413	eval-rmse:0.135788	train-rmspe:0.130369	eval-rmspe:0.137453
# [9922]	train-rmse:0.081412	eval-rmse:0.135788	train-rmspe:0.130368	eval-rmspe:0.137452
# [9923]	train-rmse:0.081411	eval-rmse:0.135786	train-rmspe:0.130367	eval-rmspe:0.13745
# [9924]	train-rmse:0.081411	eval-rmse:0.135786	train-rmspe:0.130366	eval-rmspe:0.13745
# [9925]	train-rmse:0.08141	eval-rmse:0.135786	train-rmspe:0.130357	eval-rmspe:0.13745
# [9926]	train-rmse:0.08141	eval-rmse:0.135786	train-rmspe:0.130356	eval-rmspe:0.13745
# [9927]	train-rmse:0.081409	eval-rmse:0.135786	train-rmspe:0.130356	eval-rmspe:0.13745
# [9928]	train-rmse:0.081409	eval-rmse:0.135786	train-rmspe:0.130356	eval-rmspe:0.13745
# [9929]	train-rmse:0.081409	eval-rmse:0.135785	train-rmspe:0.130355	eval-rmspe:0.137449
# [9930]	train-rmse:0.081408	eval-rmse:0.135785	train-rmspe:0.130355	eval-rmspe:0.137449
# [9931]	train-rmse:0.081408	eval-rmse:0.135785	train-rmspe:0.130355	eval-rmspe:0.137449
# [9932]	train-rmse:0.081408	eval-rmse:0.135786	train-rmspe:0.130348	eval-rmspe:0.137449
# [9933]	train-rmse:0.081407	eval-rmse:0.135785	train-rmspe:0.130347	eval-rmspe:0.137448
# [9934]	train-rmse:0.081406	eval-rmse:0.135785	train-rmspe:0.130344	eval-rmspe:0.137448
# [9935]	train-rmse:0.081406	eval-rmse:0.135785	train-rmspe:0.130342	eval-rmspe:0.137448
# [9936]	train-rmse:0.081405	eval-rmse:0.135784	train-rmspe:0.130341	eval-rmspe:0.137447
# [9937]	train-rmse:0.081405	eval-rmse:0.135783	train-rmspe:0.130339	eval-rmspe:0.137447
# [9938]	train-rmse:0.081404	eval-rmse:0.135784	train-rmspe:0.130339	eval-rmspe:0.137446
# [9939]	train-rmse:0.081404	eval-rmse:0.135783	train-rmspe:0.130337	eval-rmspe:0.137446
# [9940]	train-rmse:0.081404	eval-rmse:0.135783	train-rmspe:0.130337	eval-rmspe:0.137445
# [9941]	train-rmse:0.081403	eval-rmse:0.135783	train-rmspe:0.13034	eval-rmspe:0.137446
# [9942]	train-rmse:0.081403	eval-rmse:0.135783	train-rmspe:0.130336	eval-rmspe:0.137446
# [9943]	train-rmse:0.081402	eval-rmse:0.135783	train-rmspe:0.130335	eval-rmspe:0.137445
# [9944]	train-rmse:0.081402	eval-rmse:0.135782	train-rmspe:0.130334	eval-rmspe:0.137445
# [9945]	train-rmse:0.081401	eval-rmse:0.135782	train-rmspe:0.130334	eval-rmspe:0.137445
# [9946]	train-rmse:0.081401	eval-rmse:0.135782	train-rmspe:0.130333	eval-rmspe:0.137444
# [9947]	train-rmse:0.081401	eval-rmse:0.135782	train-rmspe:0.130333	eval-rmspe:0.137444
# [9948]	train-rmse:0.0814	eval-rmse:0.135781	train-rmspe:0.130332	eval-rmspe:0.137444
# [9949]	train-rmse:0.0814	eval-rmse:0.135782	train-rmspe:0.130332	eval-rmspe:0.137445
# [9950]	train-rmse:0.081399	eval-rmse:0.135782	train-rmspe:0.130329	eval-rmspe:0.137445
# [9951]	train-rmse:0.081399	eval-rmse:0.135781	train-rmspe:0.130327	eval-rmspe:0.137445
# [9952]	train-rmse:0.081399	eval-rmse:0.135782	train-rmspe:0.130326	eval-rmspe:0.137445
# [9953]	train-rmse:0.081398	eval-rmse:0.135781	train-rmspe:0.130326	eval-rmspe:0.137444
# [9954]	train-rmse:0.081398	eval-rmse:0.135781	train-rmspe:0.130326	eval-rmspe:0.137444
# [9955]	train-rmse:0.081397	eval-rmse:0.135781	train-rmspe:0.130326	eval-rmspe:0.137445
# [9956]	train-rmse:0.081397	eval-rmse:0.135781	train-rmspe:0.130327	eval-rmspe:0.137445
# [9957]	train-rmse:0.081397	eval-rmse:0.135781	train-rmspe:0.130327	eval-rmspe:0.137445
# [9958]	train-rmse:0.081396	eval-rmse:0.13578	train-rmspe:0.13033	eval-rmspe:0.137445
# [9959]	train-rmse:0.081396	eval-rmse:0.135781	train-rmspe:0.130329	eval-rmspe:0.137444
# [9960]	train-rmse:0.081396	eval-rmse:0.13578	train-rmspe:0.130327	eval-rmspe:0.137445
# [9961]	train-rmse:0.081395	eval-rmse:0.135781	train-rmspe:0.130327	eval-rmspe:0.137445
# [9962]	train-rmse:0.081395	eval-rmse:0.135781	train-rmspe:0.130326	eval-rmspe:0.137445
# [9963]	train-rmse:0.081395	eval-rmse:0.13578	train-rmspe:0.130323	eval-rmspe:0.137445
# [9964]	train-rmse:0.081394	eval-rmse:0.13578	train-rmspe:0.130323	eval-rmspe:0.137444
# [9965]	train-rmse:0.081394	eval-rmse:0.135781	train-rmspe:0.130323	eval-rmspe:0.137445
# [9966]	train-rmse:0.081393	eval-rmse:0.13578	train-rmspe:0.130323	eval-rmspe:0.137444
# [9967]	train-rmse:0.081393	eval-rmse:0.13578	train-rmspe:0.130324	eval-rmspe:0.137444
# [9968]	train-rmse:0.081392	eval-rmse:0.13578	train-rmspe:0.130319	eval-rmspe:0.137444
# [9969]	train-rmse:0.081392	eval-rmse:0.13578	train-rmspe:0.130318	eval-rmspe:0.137444
# [9970]	train-rmse:0.081391	eval-rmse:0.13578	train-rmspe:0.130318	eval-rmspe:0.137445
# [9971]	train-rmse:0.081391	eval-rmse:0.135779	train-rmspe:0.130317	eval-rmspe:0.137445
# [9972]	train-rmse:0.08139	eval-rmse:0.135779	train-rmspe:0.130314	eval-rmspe:0.137444
# [9973]	train-rmse:0.08139	eval-rmse:0.135779	train-rmspe:0.130314	eval-rmspe:0.137444
# [9974]	train-rmse:0.081389	eval-rmse:0.135779	train-rmspe:0.130311	eval-rmspe:0.137444
# [9975]	train-rmse:0.081389	eval-rmse:0.135779	train-rmspe:0.130312	eval-rmspe:0.137444
# [9976]	train-rmse:0.081389	eval-rmse:0.135779	train-rmspe:0.130313	eval-rmspe:0.137443
# [9977]	train-rmse:0.081389	eval-rmse:0.135778	train-rmspe:0.130311	eval-rmspe:0.137444
# [9978]	train-rmse:0.081388	eval-rmse:0.135778	train-rmspe:0.13031	eval-rmspe:0.137444
# [9979]	train-rmse:0.081388	eval-rmse:0.135778	train-rmspe:0.130309	eval-rmspe:0.137444
# [9980]	train-rmse:0.081388	eval-rmse:0.135778	train-rmspe:0.13031	eval-rmspe:0.137444
# [9981]	train-rmse:0.081387	eval-rmse:0.135779	train-rmspe:0.130311	eval-rmspe:0.137444
# [9982]	train-rmse:0.081387	eval-rmse:0.135779	train-rmspe:0.130311	eval-rmspe:0.137445
# [9983]	train-rmse:0.081387	eval-rmse:0.135779	train-rmspe:0.130308	eval-rmspe:0.137444
# [9984]	train-rmse:0.081386	eval-rmse:0.135778	train-rmspe:0.130308	eval-rmspe:0.137443
# [9985]	train-rmse:0.081386	eval-rmse:0.135778	train-rmspe:0.130307	eval-rmspe:0.137443
# [9986]	train-rmse:0.081385	eval-rmse:0.135777	train-rmspe:0.130303	eval-rmspe:0.137443
# [9987]	train-rmse:0.081385	eval-rmse:0.135777	train-rmspe:0.130302	eval-rmspe:0.137444
# [9988]	train-rmse:0.081384	eval-rmse:0.135777	train-rmspe:0.130303	eval-rmspe:0.137444
# [9989]	train-rmse:0.081384	eval-rmse:0.135778	train-rmspe:0.130301	eval-rmspe:0.137444
# [9990]	train-rmse:0.081384	eval-rmse:0.135777	train-rmspe:0.130301	eval-rmspe:0.137443
# [9991]	train-rmse:0.081383	eval-rmse:0.135776	train-rmspe:0.130301	eval-rmspe:0.137443
# [9992]	train-rmse:0.081383	eval-rmse:0.135776	train-rmspe:0.130301	eval-rmspe:0.137442
# [9993]	train-rmse:0.081382	eval-rmse:0.135777	train-rmspe:0.1303	eval-rmspe:0.137442
# [9994]	train-rmse:0.081381	eval-rmse:0.135775	train-rmspe:0.130298	eval-rmspe:0.13744
# [9995]	train-rmse:0.081381	eval-rmse:0.135776	train-rmspe:0.130299	eval-rmspe:0.137441
# [9996]	train-rmse:0.08138	eval-rmse:0.135777	train-rmspe:0.130299	eval-rmspe:0.137441
# [9997]	train-rmse:0.08138	eval-rmse:0.135776	train-rmspe:0.130297	eval-rmspe:0.137441
# [9998]	train-rmse:0.08138	eval-rmse:0.135775	train-rmspe:0.130293	eval-rmspe:0.137441
# [9999]	train-rmse:0.081379	eval-rmse:0.135773	train-rmspe:0.130292	eval-rmspe:0.137439

# %%
# Evaluation the model by rmspe
validation_x = xgb.DMatrix(X_valid[features])
validation_y = X_valid.Sales
predicts = np.expm1(model_final.predict(validation_x))*0.98
validation_result=rmspe( validation_y,predicts)
print(validation_result)
# Out:
# 0.13790414024093478

# %%
# Testing stage, thus not implement
import pickle # Save model for later training

with open('RossmanSalesRegreesion.pickle','wb') as f:
    pickle.dump(gbm,f)

pickle_in=open('RossmanSalesRegreesion.pickle','rb')
gbm=pickle.load(pickle_in)

# %% [markdown]
# ## Predict test dataset

# %%
unseen = xgb.DMatrix(test_data[features])
test_p = model_final.predict(unseen)

result = pd.DataFrame({'Id': test['Id'], 
                          'Sales': np.expm1(test_p)*0.98})
result.to_csv("output_XGB.csv", index=False)

# %% [markdown]
# ### Extracting Feature Importance

# %%
def create_feature_map(features):
    outfile = open('xgb.fmap', 'w')
    for i, feat in enumerate(features):
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
    outfile.close()

# %%
# XGB feature importances
# Based on https://www.kaggle.com/mmueller/liberty-mutual-group-property-inspection-prediction/xgb-feature-importance-python/code

create_feature_map(features)
importance = model_final.get_fscore(fmap='xgb.fmap')
importance = sorted(importance.items(), key=operator.itemgetter(1))

df = pd.DataFrame(importance, columns=['feature', 'fscore'])
df['fscore'] = df['fscore'] / df['fscore'].sum()

featp = df.plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
fig_featp = featp.get_figure()
fig_featp.savefig('feature_importance_xgb.png', bbox_inches='tight', pad_inches=1)

# %%
# Import functionality for cloning a model
from sklearn.base import clone

# Reduce the feature space
X_train_reduced = X_train[X_train.columns.values[(np.argsort(importances)[::-1])[:5]]]
X_test_reduced = X_test[X_test.columns.values[(np.argsort(importances)[::-1])[:5]]]

# Train on the "best" model found from grid search earlier
clf = (clone(best_clf)).fit(X_train_reduced, y_train)

# Make new predictions
reduced_predictions = clf.predict(X_test_reduced)

# Report scores from the final model using both versions of data
print ("Final Model trained on full data\n------")
print ("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print ("F-score on testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
print ("\nFinal Model trained on reduced data\n------")
print ("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, reduced_predictions)))
print ("F-score on testing data: {:.4f}".format(fbeta_score(y_test, reduced_predictions, beta = 0.5)))

# %% [markdown]
# ### Future work

# %%
# save for future work

from tqdm import tqdm # show features building progress
# need improvement:https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.shift.html
# progress bar: tqdm
# build more features depending on time and sales

def build_time_features(features, train, test):
    train.set_index('Date',inplace=True)
    test.set_index('Date',inplace=True)
    train.sort_index(ascending = True,inplace=True)
    test.sort_index(ascending = True,inplace=True)
    features.append('prevyear_dps_med')
    for storeid in tqdm(train.Store.unique()):
        for promoid in train.Promo.unique():
                prevyear_dps=train[(train.Store==storeid)&(train.Promo==promoid)].groupby(id)[sales].shift(365)
                train.loc[(train.Store==storeid)&(train.Promo==promoid),'prevyear_dps_med']=prevyear_dps
                test.loc[(test.Store==storeid)&(test.Promo==promoid),'prevyear_dps_med'] = prevyear_dps
    return train,test

build_time_features(features, train_data,test_data)
